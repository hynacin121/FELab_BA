# %% [markdown]
# ## 1. Define Classes

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cufflinks as cf
cf.go_offline(connected=True)
from scipy import optimize 
from datetime import datetime
from dateutil.relativedelta import relativedelta
# %matplotlib inline

try:
  import pandas_datareader.data as web
  import chart_studio as py
except:
  # !pip install pip pandas-datareader
  # !pip install chart_studio
  import pandas_datareader.data as web
  import chart_studio as py
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
class Asset():
  def __init__(self, ticker, name, start, end):
    self.ticker = ticker
    self.name = name
    
    self.start = start
    self.end = end

    # 데이터 불러오기
    self.data = web.get_data_yahoo(self.ticker, self.start, self.end)
    self.date = self.data.index

    self.ratio = 0
    self.leverage = 0
    self.price = None
    self.change = None

  def put_ratio_leverage(self, ratio, leverage):
    self.ratio = ratio
    self.leverage = leverage

  def put_price_change(self):
    self.price = self.data['Adj Close']
    self.change = np.multiply(self.price.pct_change().to_list(), [100 * self.leverage])

  def get_date(self):
    return self.date

  def get_change(self):
    return self.change

  def get_name(self):
    return self.name

# %%
class GMV_Asset(Asset):
    def __init__(self, ticker_list, start, end):
        self.ticker_list = ticker_list
        self.start = start
        self.end = end
        self.df = pd.DataFrame(columns=self.ticker_list)
        self.non_zero_assets = [] 
        self.non_zero_weights = []
        self.asset_list = []
        
    def create_df(self):
        for stock in self.ticker_list:
            asset = Asset(stock, stock, self.start, self.end)
            self.asset_list.append(asset)
            self.df[stock] = asset.data["Adj Close"]

            if stock == self.ticker_list[0]:
                self.df['date'] = asset.data.index
                self.df.set_index('date', inplace=True)
            
    def get_returns(self):
        return self.df.pct_change()

    def get_mean_returns(self):
        return self.get_returns().mean()
    
    def get_cov_matrix(self):
        return self.get_returns().cov()
    
    def get_non_zero_weights(self, weights):
        for i in range(len(weights)):
            if weights[i] != 0:
                self.non_zero_weights.append(weights[i])
                self.non_zero_assets.append(self.asset_list[i])

# %%
class Portfolio():
  def __init__(self, name, assets, ratios, leverages, initial_balance, rebalancing_interval, gmv_weights=[]):
    self.name = name
    
    # list of class asset elements
    self.assets = assets

    # Assert all the dates for assets are equal and set portfolio start, end dates
    dates = [each.get_date() for each in self.assets]
    lendates = [len(each) for each in dates]
    assert len(set(lendates)) == 1
    self.date = dates[0]

    self.ratios = [each / sum(ratios) for each in ratios]
    self.leverages = leverages

    for i in range(len(self.assets)):
      self.assets[i].put_ratio_leverage(self.ratios[i], self.leverages[i])
      self.assets[i].put_price_change()

    self.initial_balance = initial_balance  
    self.rebalancing_interval = rebalancing_interval

    self.gmv_weights = []     # weights for gmv
    self.backtest_df = None
    self.backtest_result_df = None
    self.summary = None

  def backtest(self):
    # 첫 거래일
    balances = []
    
    asset_df = pd.DataFrame()
    for i in range(len(self.assets)):
      asset_df[i] = self.assets[i].data["Adj Close"].pct_change()
    print("EUM100: ", asset_df.head(50))
    
    for i in range(len(self.assets)):
      balance = [self.initial_balance * self.ratios[i]]
      balances.append(balance)
    
    total_balance = [self.initial_balance]
    next_rebalancing = [self.date[0] + relativedelta(months=self.rebalancing_interval)]

    # 이후 거래일
    for i in range(1, len(self.date)):
      total_balance_tmp = 0

      if self.date[i] >= next_rebalancing[i-1]: # 리밸런싱하는 날
        # 다음 리밸런싱 날짜 추가
        print("EUM0 현재 날짜 정보: ", self.date[i])
        next_rebalancing.append(next_rebalancing[i-1] + relativedelta(months=self.rebalancing_interval))
        
        if self.name == "GMV":
          GMV = GMVPortfolio(asset_df.mean(), asset_df.cov(), num_portfolios=25000, risk_free_rate=0.0178)
          self.gmv_weights = [round(i, 2) for i in GMV.min_variance().x]
          print("EUM2 현재 weight: ", self.gmv_weights)
        
          for j in range(len(self.assets)):
              print("EUM9 현재 주식 번호: ", j)
              balance = total_balance[i-1] * self.gmv_weights[j] * (1 + self.assets[j].get_change()[i] / 100)
              balances[j].append(balance)
              total_balance_tmp += balances[j][i]
            
              if j > 0:
#                 print("EUM1 이전 주식 가격: ", asset_df[j][i - 1])    
#                 print("EUM2 현재 주식 가격: ", asset_df[j][i])
                print("EUM3 주식 가격 차이: ", asset_df[j][i])
                print()
                print("EUM4 이전 투자 금액: ", balances[j][i -1])
                print("EUM5 현재 투자 금액: ", balances[j][i])
                
                ret = (balances[j][i]/balances[j][i-1]) - 1
                
                print("EUM5 투자 금액 차이: ", ret)
                print("EUM6 이상한 숫자   : ", 1 + self.assets[j].get_change()[i] / 100)
                print("--------------------------------------------------------------")
                print("EUM7 수익률 업데이트: ", asset_df[j][i], " -> ", ret)
                asset_df[j][i] = ret
        else:
          for j in range(len(self.assets)):
              balance = total_balance[i-1] * self.ratios[j] * (1 + self.assets[j].get_change()[i] / 100)
              balances[j].append(balance)
              total_balance_tmp += balances[j][i]
      else:
        # 이전 리밸런싱 날짜랑 동일하게
        next_rebalancing.append(next_rebalancing[i-1])
        for j in range(len(self.assets)):
          try:
            balances[j].append(balances[j][i-1] * (1 + self.assets[j].get_change()[i] / 100))
          except:
            balances[j].append(balances[j][i-1])
          total_balance_tmp += balances[j][i]
      total_balance.append(total_balance_tmp)

    df = pd.DataFrame()
    df['Date'] = self.date
    df.set_index('Date', inplace=True)
    df['Total'] = total_balance

    for i in range(len(self.assets)):
      df[self.assets[i].get_name()] = balances[i]
    
    print('Portfolio Backtest Complete')
    self.backtest_df = df

    return df

  def balance_result(self, balance):
    change = [0]
    cum_return = [0]
    prev_high = [0]
    prev_high_tmp = 0
    drawdown = [0]
    mdd = [0]
    mdd_tmp = 0
    CAGR = [0]
    stdev = [0]
    sharpe = [0]

    time_period = (self.date[-1] - self.date[0]).days / 365

    for i in range(1, len(self.date)):
      change.append((balance[i] / balance[i-1] - 1) * 100)
      
      cum_return.append((balance[i] / balance[0] - 1) * 100)

      if prev_high_tmp < cum_return[i]:
        prev_high_tmp = cum_return[i]
      else:
        prev_high_tmp = prev_high_tmp
      prev_high.append(prev_high_tmp)

      CAGR.append(((balance[i] / balance[0]) ** (1 / float(time_period)) - 1) * 100)

      drawdown.append(((cum_return[i] + 100) / (prev_high[i] + 100) - 1) * 100)

      if mdd_tmp > drawdown[i]:
        mdd_tmp = drawdown[i]
      else:
        mdd_tmp = mdd_tmp
      mdd.append(mdd_tmp)

      stdev.append(np.std(change))
      if stdev[i] != 0:
        sharpe.append(np.sqrt(252) * np.mean(change) / np.std(change))
      else:
        sharpe.append(0)

    return change, cum_return, prev_high, CAGR, drawdown, mdd, stdev, sharpe

  def backtest_result(self):
    df = pd.DataFrame()
    df['Date'] = self.date
    df.set_index('Date', inplace=True)
    label = ['Change', 'Cum. Return', 'Prev. High', 'CAGR', 'Drawdown', 'MDD', 'St. Dev', 'Sharpe']

    result = dict()
    for i in self.backtest_df.columns:
      result[i] = self.balance_result(self.backtest_df[i].to_list())
      df[f'{i} Balance'] = self.backtest_df[i].to_list()
      print(f'{i} Complete')
    for j in range(len(label)):
      for i in self.backtest_df.columns:
        df[f'{i} {label[j]}'] = result[i][j]

    self.backtest_result_df = df

    return df
  
  def periodic_result(self, mode):
    df = pd.DataFrame()

    for label in self.backtest_df.columns:
      return_points = []
      returns = []
      start_balance = []
      end_balance = []
      start = self.backtest_df[label].to_list()[0]
      
      if mode == 'annual':
        for i in range(1, len(self.date)):
          if self.date[i].year != self.date[i-1].year:
            return_points.append(self.date[i-1].year)
            returns.append((self.backtest_df[label].to_list()[i-1] / start - 1) * 100)
            start_balance.append(start)
            end_balance.append(self.backtest_df[label].to_list()[i-1])
            start = self.backtest_df[label].to_list()[i]
          elif self.date[i] == self.date[-1]: # 마지막 거래일
            return_points.append(self.date[i].year)
            returns.append((self.backtest_df[label].to_list()[i] / start - 1) * 100)
            start_balance.append(start)
            end_balance.append(self.backtest_df[label].to_list()[i-1])
        df[f'{label} {mode.capitalize()} Return'] = returns
        
      elif mode == 'monthly':
        for i in range(1, len(self.date)):
          if self.date[i].month != self.date[i-1].month:
            return_points.append(self.date[i-1].strftime('%Y-%m'))
            returns.append((self.backtest_df[label].to_list()[i-1] / start - 1) * 100)
            start_balance.append(start)
            end_balance.append(self.backtest_df[label].to_list()[i-1])
            start = self.backtest_df[label].to_list()[i]
          elif self.date[i] == self.date[-1]: # 마지막 거래일
            return_points.append(self.date[i].strftime('%Y-%m'))
            returns.append((self.backtest_df[label].to_list()[i] / start - 1) * 100)
            start_balance.append(start)
            end_balance.append(self.backtest_df[label].to_list()[i-1])
        df[f'{label} {mode.capitalize()} Return'] = returns

    df[f'Return {mode.capitalize()}'] = return_points
    df.set_index(f'Return {mode.capitalize()}', inplace=True)

    print(f'{mode.capitalize()} Result Complete')

    return df

  def get_name(self):
    return self.name

  def get_date(self):
    return self.date

  def get_backtest_result(self):
    return self.backtest_result_df

  def get_summary(self):
    # columns=['Detail', 'Initial Balance', 'Final Balance', 'CAGR', 'MDD', 'St. Dev', 'Sharpe Ratio']
    
    detail = ''
    for i in range(len(self.assets)):
      name = self.assets[i].get_name()
      if self.name == "GMV":
        self.ratios = self.gmv_weights
      percentage = int(self.ratios[i] * 100)

      detail += f'{name} ({percentage}%, {self.leverages[i]}x) '

    self.summary = [detail, self.backtest_result_df['Total Balance'][0], self.backtest_result_df['Total Balance'][-1],
                    str(round(self.backtest_result_df['Total CAGR'][-1], 2))+'%', str(round(self.backtest_result_df['Total MDD'][-1], 2))+'%',
                    round(self.backtest_result_df['Total St. Dev'][-1], 2), round(self.backtest_result_df['Total Sharpe'][-1], 2)]
    
    return self.summary

# %%
class Visualize():
  def __init__(self, portfolios):
    self.portfolios = portfolios

     # Assert all the dates for assets are equal and set portfolio start, end dates
    dates = [each.get_date() for each in self.portfolios]
    lendates = [len(each) for each in dates]
    assert len(set(lendates)) == 1
    self.date = dates[0]

  def line_plot(self, result, title, return_type):
#     for i in range(len(self.portfolios)):
#       plt.plot(self.date, self.portfolios[i].get_backtest_result().loc[:, f'Total {result}'], label=self.portfolios[i].get_name())
    
#     plt.title(title)
#     plt.legend(loc='best')
#     plt.yscale(return_type)
#     plt.show()
    
    data_list = []
    colm_list = []
    for i in range(len(self.portfolios)):
        data_list.append(self.portfolios[i].get_backtest_result().loc[:, f'Total {result}'])
        colm_list.append(self.portfolios[i].get_name())
    plot_df = pd.DataFrame(data_list).T
    plot_df.columns = colm_list
    plot_df.iplot(kind='line')
    
    
    
  def bar_plot(self, title, period):
#     for i in range(len(self.portfolios)):
#       if period == 'annual':
#         result = self.portfolios[i].periodic_result('annual')
#         plt.bar(result.index, result.loc[:, 'Total Annual Return'], label=self.portfolios[i].get_name())
#       elif period == 'monthly':
#         result = self.portfolios[i].periodic_result('monthly')
#         plt.bar(result.index, result.loc[:, 'Total Monthly Return'], label=self.portfolios[i].get_name())
    
#     plt.title(title)
#     plt.legend(loc='best')
#     plt.show()
    
    data_list = []
    colm_list = []
    for i in range(len(self.portfolios)):
      if period == 'annual':
        data_list.append(self.portfolios[i].periodic_result('annual').loc[:, 'Total Annual Return'])
        colm_list.append(self.portfolios[i].get_name())
      elif period == 'monthly':
        data_list.append(self.portfolios[i].periodic_result('monthly').loc[:, 'Total Monthly Return'])
        colm_list.append(self.portfolios[i].get_name())
    
    plot_df = pd.DataFrame(data_list).T
    plot_df.columns = colm_list
#     plot_df.plot.bar()
    plot_df.iplot(kind='bar', barmode='stack')

# %%
#class portfolio takes matrix of returns for every stock, and array of their weights
class GMVPortfolio:
    def __init__(self, mean_returns, cov_matrix, num_portfolios, risk_free_rate):
        self.mean_returns = mean_returns
        self.cov_matrix = cov_matrix
        self.num_portfolios = num_portfolios
        self.risk_free_rate = risk_free_rate

    def neg_sharpe_ratio(self, weights, mean_returns, cov_matrix, risk_free_rate):
        p_var, p_ret = self.portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        return -(p_ret - risk_free_rate) / p_var

    def max_sharpe_ratio(self):
        num_assets = len(self.mean_returns)
        args = (self.mean_returns, self.cov_matrix, self.risk_free_rate)
        constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
        bound = (0.0,1.0)
        bounds = tuple(bound for asset in range(num_assets))
        result = optimize.minimize(self.neg_sharpe_ratio, num_assets*[1./num_assets,], args=args,
                            method='SLSQP', bounds=bounds, constraints=constraints)
        return result
    
    def portfolio_volatility(self, weights, mean_returns, cov_matrix):
        return self.portfolio_annualised_performance(weights, mean_returns, cov_matrix)[0]

    def min_variance(self):
        num_assets = len(self.mean_returns)
        args = (self.mean_returns, self.cov_matrix)
        constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
        bound = (0.0,1.0)
        bounds = tuple(bound for asset in range(num_assets))

        result = optimize.minimize(self.portfolio_volatility, num_assets*[1./num_assets,], args=args,
                            method='SLSQP', bounds=bounds, constraints=constraints)

        return result

    def portfolio_return(self, weights):
        return self.portfolio_annualised_performance(weights, self.mean_returns, self.cov_matrix)[1]
    
    def efficient_return(self, target):
        num_assets = len(self.mean_returns)
        args = (self.mean_returns, self.cov_matrix)

        constraints = ({'type': 'eq', 'fun': lambda x: self.portfolio_return(x) - target},
                       {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
        bounds = tuple((0,1) for asset in range(num_assets))
        result = optimize.minimize(self.portfolio_volatility, num_assets*[1./num_assets,], args=args, method='SLSQP', bounds=bounds, constraints=constraints)
        return result


    def efficient_frontier(self, returns_range):
        efficients = []
        for ret in returns_range:
            efficients.append(self.efficient_return(ret))
        return efficients
    
    def portfolio_annualised_performance(self, weights, mean_returns, cov_matrix):
        returns = np.sum(self.mean_returns*weights ) *252
        std = np.sqrt(np.dot(weights.T, np.dot(self.cov_matrix, weights))) * np.sqrt(252)
        return std, returns
    
    def random_portfolios(self):
        results = np.zeros((3, self.num_portfolios))
        weights_record = []
        for i in range(self.num_portfolios):
            weights = np.random.random(self.mean_returns.shape[0])
            weights /= np.sum(weights)
            weights_record.append(weights)
            portfolio_std_dev, portfolio_return = self.portfolio_annualised_performance(weights, self.mean_returns, self.cov_matrix)
            results[0,i] = portfolio_std_dev
            results[1,i] = portfolio_return
            results[2,i] = (portfolio_return - self.risk_free_rate) / portfolio_std_dev
        return results, weights_record       
    
    def display_calculated_ef_with_random(self):
        results, _ = self.random_portfolios()

        max_sharpe = self.max_sharpe_ratio()
        sdp, rp = self.portfolio_annualised_performance(max_sharpe['x'], self.mean_returns, self.cov_matrix)
        max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
        max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
        max_sharpe_allocation = max_sharpe_allocation.T

        min_vol = self.min_variance()
        sdp_min, rp_min = self.portfolio_annualised_performance(min_vol['x'], self.mean_returns, self.cov_matrix)
        min_vol_allocation = pd.DataFrame(min_vol.x,index=df.columns,columns=['allocation'])
        min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
        min_vol_allocation = min_vol_allocation.T

        print("-"*80)
        print("Maximum Sharpe Ratio Portfolio Allocation\n")
        print("Annualised Return:", round(rp,2))
        print("Annualised Volatility:", round(sdp,2))
        print("\n")
        print(max_sharpe_allocation)
        print("-"*80)
        print("Minimum Volatility Portfolio Allocation\n")
        print("Annualised Return:", round(rp_min,2))
        print("Annualised Volatility:", round(sdp_min,2))
        print("\n")
        print(min_vol_allocation)

        plt.figure(figsize=(10, 7))
        plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
        plt.colorbar()
        plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
        plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

        target = np.linspace(rp_min, 0.32, 50)
        efficient_portfolios = self.efficient_frontier(target)
        plt.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
        plt.title('Calculated Portfolio Optimization based on Efficient Frontier')
        plt.xlabel('annualised volatility')
        plt.ylabel('annualised returns')
        plt.legend(labelspacing=0.8)
        
    def display_ef_with_selected(self):
        max_sharpe = self.max_sharpe_ratio()
        sdp, rp = self.portfolio_annualised_performance(max_sharpe['x'], self.mean_returns, self.cov_matrix)
        max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
        max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
        max_sharpe_allocation = max_sharpe_allocation.T

        min_vol = self.min_variance()
        sdp_min, rp_min = self.portfolio_annualised_performance(min_vol['x'], self.mean_returns, self.cov_matrix)
        min_vol_allocation = pd.DataFrame(min_vol.x,index=df.columns,columns=['allocation'])
        min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
        min_vol_allocation = min_vol_allocation.T

        an_vol = np.std(returns) * np.sqrt(252)
        an_rt = self.mean_returns * 252

        print("-"*80)
        print("Maximum Sharpe Ratio Portfolio Allocation\n")
        print("Annualised Return:", round(rp,2))
        print("Annualised Volatility:", round(sdp,2))
        print("\n")
        print(max_sharpe_allocation)
        print("-"*80)
        print("Minimum Volatility Portfolio Allocation\n")
        print("Annualised Return:", round(rp_min,2))
        print("Annualised Volatility:", round(sdp_min,2))
        print("\n")
        print(min_vol_allocation)
        print("-"*80)
        print("Individual Stock Returns and Volatility\n")
        for i, txt in enumerate(df.columns):
            print(txt,":","annuaised return",round(an_rt[i],2),", annualised volatility:",round(an_vol[i],2))
        print("-"*80)

        fig, ax = plt.subplots(figsize=(10, 7))
        ax.scatter(an_vol,an_rt,marker='o',s=200)

        for i, txt in enumerate(df.columns):
            ax.annotate(txt, (an_vol[i],an_rt[i]), xytext=(10,0), textcoords='offset points')
        ax.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
        ax.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

        target = np.linspace(rp_min, 0.34, 50)
        efficient_portfolios = self.efficient_frontier(target)
        ax.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
        ax.set_title('Portfolio Optimization with Individual Stocks')
        ax.set_xlabel('annualised volatility')
        ax.set_ylabel('annualised returns')
        ax.legend(labelspacing=0.8)
        
    def display_ef_with_selected_and_random(self):
        results, _ = self.random_portfolios()
        
        max_sharpe = self.max_sharpe_ratio()
        sdp, rp = self.portfolio_annualised_performance(max_sharpe['x'], self.mean_returns, self.cov_matrix)
        max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
        max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
        max_sharpe_allocation = max_sharpe_allocation.T

        min_vol = self.min_variance()
        sdp_min, rp_min = self.portfolio_annualised_performance(min_vol['x'], self.mean_returns, self.cov_matrix)
        min_vol_allocation = pd.DataFrame(min_vol.x,index=df.columns,columns=['allocation'])
        min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
        min_vol_allocation = min_vol_allocation.T

        an_vol = np.std(returns) * np.sqrt(252)
        an_rt = self.mean_returns * 252

        print("-"*80)
        print("Maximum Sharpe Ratio Portfolio Allocation\n")
        print("Annualised Return:", round(rp,2))
        print("Annualised Volatility:", round(sdp,2))
        print("\n")
        print(max_sharpe_allocation)
        print("-"*80)
        print("Minimum Volatility Portfolio Allocation\n")
        print("Annualised Return:", round(rp_min,2))
        print("Annualised Volatility:", round(sdp_min,2))
        print("\n")
        print(min_vol_allocation)
        print("-"*80)
        print("Individual Stock Returns and Volatility\n")
        for i, txt in enumerate(df.columns):
            print(txt,":","annuaised return",round(an_rt[i],2),", annualised volatility:",round(an_vol[i],2))
        print("-"*80)

        fig, ax = plt.subplots(figsize=(10, 7))
        ax.scatter(an_vol,an_rt,marker='o',s=200)
        ax.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)

        for i, txt in enumerate(df.columns):
            ax.annotate(txt, (an_vol[i],an_rt[i]), xytext=(10,0), textcoords='offset points')
        ax.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
        ax.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

        target = np.linspace(rp_min, 0.34, 50)
        efficient_portfolios = self.efficient_frontier(target)
        ax.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
        ax.set_title('Portfolio Optimization with Individual Stocks')
        ax.set_xlabel('annualised volatility')
        ax.set_ylabel('annualised returns')
        ax.legend(labelspacing=0.8)

# %% [markdown]
# ## 2. GMV Portfolio

# %% [markdown]
# ### 1) GMV - Calculation

# %%
gmv_portfolio = ['AMZN', 'AAPL', 'GOOGL', 'SBUX', 'SO', 'INTC', 'CSCO', 'MET']
gmv_asset = GMV_Asset(gmv_portfolio, '2016-01-01', '2020-10-31')
gmv_asset.create_df()

# %%
GMV = GMVPortfolio(gmv_asset.get_mean_returns(), gmv_asset.get_cov_matrix(), num_portfolios=25000, risk_free_rate=0.0178)
gmv_weights = [round(i, 2)for i in GMV.min_variance().x]
gmv_asset.get_non_zero_weights(gmv_weights)

# %%
gmv_weights
# Out:
# [0.18, 0.0, 0.12, 0.15, 0.43, 0.0, 0.12, 0.0]

# %%
gmv_portfolio = Portfolio('GMV', gmv_asset.non_zero_assets, gmv_asset.non_zero_weights, [1 for i in gmv_portfolio], 1000, 1)
gmv_backtest_df = gmv_portfolio.backtest()
backtest_result_df = gmv_portfolio.backtest_result()
gmv_annual_return_df = gmv_portfolio.periodic_result('annual')
gmv_monthly_return_df = gmv_portfolio.periodic_result('monthly')
gmv_portfolio.get_summary()
# Out:
# EUM100:                     0         1         2         3         4
# Date
# 2016-01-04       NaN       NaN       NaN       NaN       NaN
# 2016-01-05 -0.005024  0.002752  0.006694  0.007017 -0.004544
# 2016-01-06 -0.001799 -0.002889 -0.008866  0.000211 -0.010650
# 2016-01-07 -0.039058 -0.024140 -0.024772 -0.008444 -0.023068
# 2016-01-08 -0.001464 -0.013617 -0.001058 -0.007451 -0.024794
# 2016-01-11  0.017610  0.002955  0.021013  0.004719  0.019774
# 2016-01-12  0.000243  0.016738  0.028364 -0.008326  0.003166
# 2016-01-13 -0.058392 -0.034575 -0.026741  0.007535 -0.029586
# 2016-01-14  0.019233  0.016426  0.019181  0.007265  0.002439
# 2016-01-15 -0.038482 -0.028576 -0.016616  0.000636 -0.042174
# 2016-01-19  0.007541  0.012090  0.009483  0.016324  0.009738
# 2016-01-20 -0.004717 -0.000723 -0.027839 -0.016270 -0.039832
# 2016-01-21  0.005684  0.011286  0.037070 -0.007421  0.000000
# 2016-01-22  0.037147  0.025858  0.002372  0.011536  0.020524
# 2016-01-25  0.000252 -0.015883 -0.024675  0.000845 -0.008558
# 2016-01-26  0.007912  0.000232  0.015595  0.004009  0.023738
# 2016-01-27 -0.029771 -0.022091 -0.016721  0.001261 -0.012226
# 2016-01-28  0.089140  0.042811  0.028804  0.013434 -0.013657
# 2016-01-29 -0.076100  0.017440  0.024962  0.013256  0.029424
# 2016-02-01 -0.020767  0.012373  0.010367  0.020033 -0.013031
# 2016-02-02 -0.039509  0.013156 -0.008170 -0.005411 -0.027683
# 2016-02-03 -0.038091 -0.040376 -0.019275 -0.022567  0.011826
# 2016-02-04  0.009773 -0.025821 -0.020830 -0.001855  0.019048
# 2016-02-05 -0.063645 -0.035985 -0.065191 -0.004130 -0.027613
# 2016-02-08 -0.027941  0.000568 -0.006423  0.012443  0.001748
# 2016-02-09 -0.012354 -0.004459  0.005172  0.007784 -0.012211
# 2016-02-10  0.017446  0.008316  0.013230  0.000203 -0.006181
# 2016-02-11  0.027198 -0.000693 -0.003990 -0.012678  0.096401
# 2016-02-12  0.006471  0.000750  0.017116 -0.002914  0.017423
# 2016-02-16  0.027648  0.015207  0.009846  0.003757  0.029072
# 2016-02-17  0.024947  0.019968  0.021627 -0.005407  0.023994
# 2016-02-18 -0.017038 -0.019755 -0.011626  0.021744 -0.001134
# 2016-02-19  0.018857  0.006411  0.012465 -0.006139  0.004540
# 2016-02-22  0.045990  0.009611  0.020808  0.010912  0.003013
# 2016-02-23 -0.011725 -0.016131 -0.006964  0.000000 -0.019151
# 2016-02-24  0.001989  0.005033 -0.005987 -0.002444  0.007657
# 2016-02-25  0.002004  0.011402  0.011014  0.007758  0.010638
# 2016-02-26  0.000144 -0.005843 -0.006979 -0.023703 -0.007143
# 2016-02-29 -0.004881 -0.010540 -0.002228 -0.000208 -0.008709
# 2016-03-01  0.047998  0.034787  0.031438 -0.014321  0.024828
# 2016-03-02  0.002021 -0.003625 -0.007995  0.010318  0.002609
# 2016-03-03 -0.004688 -0.010670 -0.008731  0.004377 -0.001115
# 2016-03-04 -0.004069 -0.001873 -0.005759  0.009131 -0.002605
# 2016-03-07 -0.021456 -0.023856 -0.011925 -0.002879  0.012686
# 2016-03-08 -0.004513  0.001024 -0.006896  0.013611 -0.003316
# 2016-03-09 -0.001410  0.016650 -0.009202  0.008342  0.020703
# 2016-03-10 -0.000965  0.009319  0.007885  0.006255 -0.008331
# 2016-03-11  0.019108  0.017346  0.001217 -0.001604  0.017531
# 2016-03-14  0.006601  0.007209  0.018406  0.003214 -0.005743
# 2016-03-15  0.006366  0.000440  0.007332  0.007608 -0.001444
# EUM0 현재 날짜 정보:  2016-02-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.15, 0.43, 0.12]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.025821312898471893
#
# EUM4 이전 투자 금액:  118.4104080596882
# EUM5 현재 투자 금액:  113.4811858155603
# EUM5 투자 금액 차이:  -0.041628285257180986
# EUM6 이상한 숫자   :  0.9741786871015281
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.025821312898471893  ->  -0.041628285257180986
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.02082996427238193
#
# EUM4 이전 투자 금액:  153.77073512191544
# EUM5 현재 투자 금액:  142.57827932476374
# EUM5 투자 금액 차이:  -0.07278664427452908
# EUM6 이상한 숫자   :  0.9791700357276181
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.02082996427238193  ->  -0.07278664427452908
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.0018553952445469202
#
# EUM4 이전 투자 금액:  443.5317726408493
# EUM5 현재 투자 금액:  416.64475069274823
# EUM5 투자 금액 차이:  -0.060620283836740785
# EUM6 이상한 숫자   :  0.9981446047554531
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0018553952445469202  ->  -0.060620283836740785
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.01904758513746585
#
# EUM4 이전 투자 금액:  104.96023944878306
# EUM5 현재 투자 금액:  118.70792278155288
# EUM5 투자 금액 차이:  0.13097991587069702
# EUM6 이상한 숫자   :  1.0190475851374659
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.01904758513746585  ->  0.13097991587069702
# EUM0 현재 날짜 정보:  2016-03-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.14, 0.42, 0.14]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.0018727102640156978
#
# EUM4 이전 투자 금액:  113.72368320020779
# EUM5 현재 투자 금액:  120.12694761434145
# EUM5 투자 금액 차이:  0.056305461043333116
# EUM6 이상한 숫자   :  0.9981272897359843
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0018727102640156978  ->  0.056305461043333116
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.005758847227562258
#
# EUM4 이전 투자 금액:  144.4128078574555
# EUM5 현재 투자 금액:  139.6024489600191
# EUM5 투자 금액 차이:  -0.03330978026675113
# EUM6 이상한 숫자   :  0.9942411527724377
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.005758847227562258  ->  -0.03330978026675113
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.00913052964959693
#
# EUM4 이전 투자 금액:  419.29225380280593
# EUM5 현재 투자 금액:  425.0792462167844
# EUM5 투자 금액 차이:  0.013801810936149739
# EUM6 이상한 숫자   :  1.009130529649597
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.00913052964959693  ->  0.013801810936149739
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.002605406966090351
#
# EUM4 이전 투자 금액:  135.5005420497237
# EUM5 현재 투자 금액:  140.04522683329765
# EUM5 투자 금액 차이:  0.03353997493165917
# EUM6 이상한 숫자   :  0.9973945930339096
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.002605406966090351  ->  0.03353997493165917
# EUM0 현재 날짜 정보:  2016-04-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.15, 0.42, 0.14]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.005911608733609519
#
# EUM4 이전 투자 금액:  126.61678593691705
# EUM5 현재 투자 금액:  115.98387862244289
# EUM5 투자 금액 차이:  -0.08397707488619788
# EUM6 이상한 숫자   :  0.9940883912663905
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.005911608733609519  ->  -0.08397707488619788
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.012618483107815215
#
# EUM4 이전 투자 금액:  145.11993893202418
# EUM5 현재 투자 금액:  157.09276826623326
# EUM5 투자 금액 차이:  0.08250299319528587
# EUM6 이상한 숫자   :  0.9873815168921848
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.012618483107815215  ->  0.08250299319528587
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.003288275624770076
#
# EUM4 이전 투자 금액:  451.9144359115967
# EUM5 현재 투자 금액:  444.0161817362799
# EUM5 투자 금액 차이:  -0.01747732213817088
# EUM6 이상한 숫자   :  0.9967117243752299
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.003288275624770076  ->  -0.01747732213817088
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.010200764945022534
#
# EUM4 이전 투자 금액:  149.92158222897663
# EUM5 현재 투자 금액:  146.97893292067837
# EUM5 투자 금액 차이:  -0.01962792324192475
# EUM6 이상한 숫자   :  0.9897992350549775
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.010200764945022534  ->  -0.01962792324192475
# EUM0 현재 날짜 정보:  2016-05-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.1, 0.15, 0.42, 0.14]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.004135837425447431
#
# EUM4 이전 투자 금액:  107.39180753191826
# EUM5 현재 투자 금액:  104.8471046375649
# EUM5 투자 금액 차이:  -0.02369550297025258
# EUM6 이상한 숫자   :  1.0041358374254474
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.004135837425447431  ->  -0.02369550297025258
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.0024888740056616676
#
# EUM4 이전 투자 금액:  147.17652644530784
# EUM5 현재 투자 금액:  157.0127047855764
# EUM5 투자 금액 차이:  0.06683252131190764
# EUM6 이상한 숫자   :  1.0024888740056617
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0024888740056616676  ->  0.06683252131190764
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.017029741573688195
#
# EUM4 이전 투자 금액:  435.14101910810905
# EUM5 현재 투자 금액:  446.0123849700544
# EUM5 투자 금액 차이:  0.024983546447144844
# EUM6 이상한 숫자   :  1.0170297415736882
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.017029741573688195  ->  0.024983546447144844
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.015636618584716544
#
# EUM4 이전 투자 금액:  140.29334512916876
# EUM5 현재 투자 금액:  143.8955819007081
# EUM5 투자 금액 차이:  0.025676462188728433
# EUM6 이상한 숫자   :  0.9843633814152835
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.015636618584716544  ->  0.025676462188728433
# EUM0 현재 날짜 정보:  2016-06-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.15, 0.42, 0.14]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.007881917631650803
#
# EUM4 이전 투자 금액:  108.45662512099977
# EUM5 현재 투자 금액:  115.99146746526065
# EUM5 투자 금액 차이:  0.06947332480477453
# EUM6 이상한 숫자   :  0.9921180823683492
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.007881917631650803  ->  0.06947332480477453
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.017945477828871903
#
# EUM4 이전 투자 금액:  152.05645195088573
# EUM5 현재 투자 금액:  162.2877611840002
# EUM5 투자 금액 차이:  0.06728625521539322
# EUM6 이상한 숫자   :  1.017945477828872
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.017945477828871903  ->  0.06728625521539322
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.0009963455158833456
#
# EUM4 이전 투자 금액:  440.669325666119
# EUM5 현재 투자 금액:  445.95019683237655
# EUM5 투자 금액 차이:  0.011983750305912366
# EUM6 이상한 숫자   :  0.9990036544841167
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0009963455158833456  ->  0.011983750305912366
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0010297895631303788
#
# EUM4 이전 투자 금액:  158.53546888707558
# EUM5 현재 투자 금액:  148.64508919274283
# EUM5 투자 금액 차이:  -0.06238591126492732
# EUM6 이상한 숫자   :  0.9989702104368696
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0010297895631303788  ->  -0.06238591126492732
# EUM0 현재 날짜 정보:  2016-07-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.14]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.007546617883227746
#
# EUM4 이전 투자 금액:  112.84406766936912
# EUM5 현재 투자 금액:  119.70974304794491
# EUM5 투자 금액 차이:  0.06084214722471781
# EUM6 이상한 숫자   :  0.9924533821167723
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.007546617883227746  ->  0.06084214722471781
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.003860553818433865
#
# EUM4 이전 투자 금액:  166.37489091470755
# EUM5 현재 투자 금액:  152.9237260157424
# EUM5 투자 금액 차이:  -0.08084852723275959
# EUM6 이상한 숫자   :  0.9961394461815661
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.003860553818433865  ->  -0.08084852723275959
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.00780221414633453
#
# EUM4 이전 투자 금액:  478.8649197516495
# EUM5 현재 투자 금액:  464.14245595314503
# EUM5 투자 금액 차이:  -0.030744502658787143
# EUM6 이상한 숫자   :  1.0078022141463345
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.00780221414633453  ->  -0.030744502658787143
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.007358125366082047
#
# EUM4 이전 투자 금액:  147.11267835291935
# EUM5 현재 투자 금액:  152.38679147798945
# EUM5 투자 금액 차이:  0.03585084021390483
# EUM6 이상한 숫자   :  0.992641874633918
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.007358125366082047  ->  0.03585084021390483
# EUM0 현재 날짜 정보:  2016-08-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.002090300588142968
#
# EUM4 이전 투자 금액:  135.6786220297685
# EUM5 현재 투자 금액:  121.97421272816928
# EUM5 투자 금액 차이:  -0.10100640098329128
# EUM6 이상한 숫자   :  0.997909699411857
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.002090300588142968  ->  -0.10100640098329128
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.009295674812257237
#
# EUM4 이전 투자 금액:  151.21270227801813
# EUM5 현재 투자 금액:  154.11900245568987
# EUM5 투자 금액 차이:  0.019219947358180667
# EUM6 이상한 숫자   :  0.9907043251877428
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.009295674812257237  ->  0.019219947358180667
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.002262166263595322
#
# EUM4 이전 투자 금액:  453.7902183770371
# EUM5 현재 투자 금액:  467.7509969516438
# EUM5 투자 금액 차이:  0.030764829229984025
# EUM6 이상한 숫자   :  1.0022621662635953
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.002262166263595322  ->  0.030764829229984025
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.002604293054524476
#
# EUM4 이전 투자 금액:  165.24257017663754
# EUM5 현재 투자 금액:  167.11095210766896
# EUM5 투자 금액 차이:  0.011306904322743172
# EUM6 이상한 숫자   :  1.0026042930545245
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.002604293054524476  ->  0.011306904322743172
# EUM0 현재 날짜 정보:  2016-09-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.14, 0.42, 0.14]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.013992275380406038
#
# EUM4 이전 투자 금액:  121.91607438208725
# EUM5 현재 투자 금액:  135.8231709055095
# EUM5 투자 금액 차이:  0.11407106564009895
# EUM6 이상한 숫자   :  1.013992275380406
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.013992275380406038  ->  0.11407106564009895
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.00284813095148595
#
# EUM4 이전 투자 금액:  156.23251200418503
# EUM5 현재 투자 금액:  155.82865276167956
# EUM5 투자 금액 차이:  -0.002584988472147498
# EUM6 이상한 숫자   :  0.997151869048514
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00284813095148595  ->  -0.002584988472147498
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.006370556838144692
#
# EUM4 이전 투자 금액:  460.6630087452098
# EUM5 현재 투자 금액:  471.80787476459994
# EUM5 투자 금액 차이:  0.02419309952789006
# EUM6 이상한 숫자   :  1.0063705568381447
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.006370556838144692  ->  0.02419309952789006
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.0012565998409481693
#
# EUM4 이전 투자 금액:  172.69939200786172
# EUM5 현재 투자 금액:  156.47011439775386
# EUM5 투자 금액 차이:  -0.09397414444498486
# EUM6 이상한 숫자   :  1.0012565998409482
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0012565998409481693  ->  -0.09397414444498486
# EUM0 현재 날짜 정보:  2016-10-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.003011036170105452
#
# EUM4 이전 투자 금액:  134.538931666094
# EUM5 현재 투자 금액:  123.23231476340287
# EUM5 투자 금액 차이:  -0.0840397404875527
# EUM6 이상한 숫자   :  1.0030110361701055
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.003011036170105452  ->  -0.0840397404875527
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.00575778474542632
#
# EUM4 이전 투자 금액:  149.7646583731287
# EUM5 현재 투자 금액:  155.46994479997065
# EUM5 투자 금액 차이:  0.038095011792619315
# EUM6 이상한 숫자   :  0.9942422152545737
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00575778474542632  ->  0.038095011792619315
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.017350160909156864
#
# EUM4 이전 투자 금액:  459.0465903920326
# EUM5 현재 투자 금액:  460.9717246879413
# EUM5 투자 금액 차이:  0.004193766681208855
# EUM6 이상한 숫자   :  0.9826498390908431
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.017350160909156864  ->  0.004193766681208855
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.004762020622570029
#
# EUM4 이전 투자 금액:  155.93168667442689
# EUM5 현재 투자 금액:  166.74177077775596
# EUM5 투자 금액 차이:  0.06932576908437915
# EUM6 이상한 숫자   :  0.99523797937743
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004762020622570029  ->  0.06932576908437915
# EUM0 현재 날짜 정보:  2016-11-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.0013935576420901485
#
# EUM4 이전 투자 금액:  120.07011450554386
# EUM5 현재 투자 금액:  118.85945807230395
# EUM5 투자 금액 차이:  -0.010082912290251933
# EUM6 이상한 숫자   :  0.9986064423579099
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0013935576420901485  ->  -0.010082912290251933
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.018929774680835676
#
# EUM4 이전 투자 금액:  150.35828393963837
# EUM5 현재 투자 금액:  154.35439007189166
# EUM5 투자 금액 차이:  0.02657722625949588
# EUM6 이상한 숫자   :  1.0189297746808357
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.018929774680835676  ->  0.02657722625949588
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.005556337673441769
#
# EUM4 이전 투자 금액:  466.0585692894675
# EUM5 현재 투자 금액:  451.93520330884803
# EUM5 투자 금액 차이:  -0.030303843575178457
# EUM6 이상한 숫자   :  0.9944436623265582
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.005556337673441769  ->  -0.030303843575178457
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.004287489739879358
#
# EUM4 이전 투자 금액:  161.26348524169345
# EUM5 현재 투자 금액:  161.61137298932977
# EUM5 투자 금액 차이:  0.0021572629855723946
# EUM6 이상한 숫자   :  0.9957125102601206
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004287489739879358  ->  0.0021572629855723946
# EUM0 현재 날짜 정보:  2016-12-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.017999566144691004
#
# EUM4 이전 투자 금액:  116.32736751969666
# EUM5 현재 투자 금액:  118.22104536777537
# EUM5 투자 금액 차이:  0.016278867892012272
# EUM6 이상한 숫자   :  1.017999566144691
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.017999566144691004  ->  0.016278867892012272
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.005069132182345504
#
# EUM4 이전 투자 금액:  168.18045178894468
# EUM5 현재 투자 금액:  148.55199478295262
# EUM5 투자 금액 차이:  -0.11671069257576072
# EUM6 이상한 숫자   :  1.0050691321823455
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.005069132182345504  ->  -0.11671069257576072
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.0023526172412322577
#
# EUM4 이전 투자 금액:  426.6553424546966
# EUM5 현재 투자 금액:  444.4514591064483
# EUM5 투자 금액 차이:  0.04171075545278402
# EUM6 이상한 숫자   :  1.0023526172412323
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0023526172412322577  ->  0.04171075545278402
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.00957266063105
#
# EUM4 이전 투자 금액:  156.579423805664
# EUM5 현재 투자 금액:  159.8760307833227
# EUM5 투자 금액 차이:  0.02105389646694733
# EUM6 이상한 숫자   :  1.00957266063105
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.00957266063105  ->  0.02105389646694733
# EUM0 현재 날짜 정보:  2017-01-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.00029701393729586467
#
# EUM4 이전 투자 금액:  122.74651334867758
# EUM5 현재 투자 금액:  119.8171699140352
# EUM5 투자 금액 차이:  -0.023864982839237103
# EUM6 이상한 숫자   :  0.9997029860627041
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00029701393729586467  ->  -0.023864982839237103
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.011562770123717536
#
# EUM4 이전 투자 금액:  142.99745944919357
# EUM5 현재 투자 금액:  154.303670003545
# EUM5 투자 금액 차이:  0.07906581416132408
# EUM6 이상한 숫자   :  1.0115627701237175
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.011562770123717536  ->  0.07906581416132408
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.0010195341850346429
#
# EUM4 이전 투자 금액:  465.028761579889
# EUM5 현재 투자 금액:  457.153100202316
# EUM5 투자 금액 차이:  -0.016935858657034952
# EUM6 이상한 숫자   :  0.9989804658149654
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0010195341850346429  ->  -0.016935858657034952
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.00594445672834909
#
# EUM4 이전 투자 금액:  165.34419583748794
# EUM5 현재 투자 금액:  162.46405672393112
# EUM5 투자 금액 차이:  -0.017419051808674535
# EUM6 이상한 숫자   :  0.9940555432716509
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00594445672834909  ->  -0.017419051808674535
# EUM0 현재 날짜 정보:  2017-02-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.0018167732255911506
#
# EUM4 이전 투자 금액:  121.65053637874074
# EUM5 현재 투자 금액:  122.20428388854228
# EUM5 투자 금액 차이:  0.004551952883113719
# EUM6 이상한 숫자   :  1.0018167732255912
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0018167732255911506  ->  0.004551952883113719
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.01216843459505812
#
# EUM4 이전 투자 금액:  151.74066869654268
# EUM5 현재 투자 금액:  157.13982730905843
# EUM5 투자 금액 차이:  0.03558148688083884
# EUM6 이상한 숫자   :  1.0121684345950581
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.01216843459505812  ->  0.03558148688083884
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.0014335428127645322
#
# EUM4 이전 투자 금액:  455.660034585568
# EUM5 현재 투자 금액:  465.0843336221935
# EUM5 투자 금액 차이:  0.02068274222293187
# EUM6 이상한 숫자   :  0.9985664571872355
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0014335428127645322  ->  0.02068274222293187
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0006386316203800257
#
# EUM4 이전 투자 금액:  169.0489568762275
# EUM5 현재 투자 금액:  166.23377325252739
# EUM5 투자 금액 차이:  -0.016653067109791753
# EUM6 이상한 숫자   :  0.99936136837962
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0006386316203800257  ->  -0.016653067109791753
# EUM0 현재 날짜 정보:  2017-03-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.002131716118814575
#
# EUM4 이전 투자 금액:  126.28857144322073
# EUM5 현재 투자 금액:  127.9410325584341
# EUM5 투자 금액 차이:  0.01308480329082129
# EUM6 이상한 숫자   :  0.9978682838811854
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.002131716118814575  ->  0.01308480329082129
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.007355526179576022
#
# EUM4 이전 투자 금액:  161.7282710748371
# EUM5 현재 투자 금액:  161.98161019268292
# EUM5 투자 금액 차이:  0.0015664491814706416
# EUM6 이상한 숫자   :  0.992644473820424
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.007355526179576022  ->  0.0015664491814706416
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.0025806962370579223
#
# EUM4 이전 투자 금액:  486.0706167006705
# EUM5 현재 투자 금액:  488.2823280292012
# EUM5 투자 금액 차이:  0.004550185204658774
# EUM6 이상한 숫자   :  0.9974193037629421
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0025806962370579223  ->  0.004550185204658774
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0029161472600842675
#
# EUM4 이전 투자 금액:  182.11361706060646
# EUM5 현재 투자 금액:  174.32789622300098
# EUM5 투자 금액 차이:  -0.04275199715029787
# EUM6 이상한 숫자   :  0.9970838527399157
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0029161472600842675  ->  -0.04275199715029787
# EUM0 현재 날짜 정보:  2017-04-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.004878894281623913
#
# EUM4 이전 투자 금액:  129.37254608050662
# EUM5 현재 투자 금액:  128.42726261325726
# EUM5 투자 금액 차이:  -0.00730667746664837
# EUM6 이상한 숫자   :  0.9951211057183761
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004878894281623913  ->  -0.00730667746664837
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.002053179583464404
#
# EUM4 이전 투자 금액:  167.0113797749634
# EUM5 현재 투자 금액:  163.9170153630788
# EUM5 투자 금액 차이:  -0.01852786568229081
# EUM6 이상한 숫자   :  0.9979468204165356
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.002053179583464404  ->  -0.01852786568229081
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.0012011660938255897
#
# EUM4 이전 투자 금액:  485.5608831889114
# EUM5 현재 투자 금액:  493.3546665010689
# EUM5 투자 금액 차이:  0.01605109386277559
# EUM6 이상한 숫자   :  1.0012011660938256
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0012011660938255897  ->  0.01605109386277559
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.003604778090497529
#
# EUM4 이전 투자 금액:  171.21762339018056
# EUM5 현재 투자 금액:  176.62109893654488
# EUM5 투자 금액 차이:  0.03155910845725596
# EUM6 이상한 숫자   :  1.0036047780904975
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.003604778090497529  ->  0.03155910845725596
# EUM0 현재 날짜 정보:  2017-05-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.006610742174491202
#
# EUM4 이전 투자 금액:  142.8701898340863
# EUM5 현재 투자 금액:  133.43439248045055
# EUM5 투자 금액 차이:  -0.06604454970342966
# EUM6 이상한 숫자   :  1.0066107421744912
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.006610742174491202  ->  -0.06604454970342966
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.0039611227090898815
#
# EUM4 이전 투자 금액:  170.29715976121238
# EUM5 현재 투자 금액:  169.37857236073964
# EUM5 투자 금액 차이:  -0.005394026546072572
# EUM6 이상한 숫자   :  1.0039611227090899
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0039611227090898815  ->  -0.005394026546072572
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.006468814822417901
#
# EUM4 이전 투자 금액:  487.929912108869
# EUM5 현재 투자 금액:  509.40493747472664
# EUM5 투자 금액 차이:  0.04401252071847983
# EUM6 이상한 숫자   :  1.006468814822418
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.006468814822417901  ->  0.04401252071847983
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0020438012441501563
#
# EUM4 이전 투자 금액:  181.06171508966835
# EUM5 현재 투자 금액:  180.39158560496327
# EUM5 투자 금액 차이:  -0.0037011108857176733
# EUM6 이상한 숫자   :  0.9979561987558498
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0020438012441501563  ->  -0.0037011108857176733
# EUM0 현재 날짜 정보:  2017-06-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.007790235919029165
#
# EUM4 이전 투자 금액:  139.2205782478833
# EUM5 현재 투자 금액:  138.41811558953316
# EUM5 투자 금액 차이:  -0.00576396584793204
# EUM6 이상한 숫자   :  1.0077902359190292
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.007790235919029165  ->  -0.00576396584793204
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.004646044337451416
#
# EUM4 이전 투자 금액:  180.53304396876442
# EUM5 현재 투자 금액:  173.9945653259878
# EUM5 투자 금액 차이:  -0.03621762808091744
# EUM6 이상한 숫자   :  0.9953539556625486
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004646044337451416  ->  -0.03621762808091744
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.003920625807630307
#
# EUM4 이전 투자 금액:  528.0277146374245
# EUM5 현재 투자 금액:  522.3641200905845
# EUM5 투자 금액 차이:  -0.010725941820551976
# EUM6 이상한 숫자   :  0.9960793741923697
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.003920625807630307  ->  -0.010725941820551976
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.006879242673769603
#
# EUM4 이전 투자 금액:  168.78065376514323
# EUM5 현재 투자 금액:  186.0044863267173
# EUM5 투자 금액 차이:  0.10204861859073544
# EUM6 이상한 숫자   :  0.9931207573262304
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.006879242673769603  ->  0.10204861859073544
# EUM0 현재 날짜 정보:  2017-07-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.013921201016991569
#
# EUM4 이전 투자 금액:  126.77802424824921
# EUM5 현재 투자 금액:  142.44478504091933
# EUM5 투자 금액 차이:  0.12357631289467319
# EUM6 이상한 숫자   :  1.0139212010169916
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.013921201016991569  ->  0.12357631289467319
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.005322083759409124
#
# EUM4 이전 투자 금액:  157.69698059689668
# EUM5 현재 투자 금액:  163.03153419813324
# EUM5 투자 금액 차이:  0.0338278740724447
# EUM6 이상한 숫자   :  0.9946779162405909
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.005322083759409124  ->  0.0338278740724447
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.004826573000338619
#
# EUM4 이전 투자 금액:  489.87690537274267
# EUM5 현재 투자 금액:  489.3382509491403
# EUM5 투자 금액 차이:  -0.0010995709691448141
# EUM6 이상한 숫자   :  0.9951734269996614
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004826573000338619  ->  -0.0010995709691448141
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.002255206938772236
#
# EUM4 이전 투자 금액:  183.48615853179712
# EUM5 현재 투자 금액:  176.00730136293777
# EUM5 투자 금액 차이:  -0.040759789341621167
# EUM6 이상한 숫자   :  1.0022552069387722
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.002255206938772236  ->  -0.040759789341621167
# EUM0 현재 날짜 정보:  2017-08-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.005838551851160778
#
# EUM4 이전 투자 금액:  143.6732544913323
# EUM5 현재 투자 금액:  133.47209295439282
# EUM5 투자 금액 차이:  -0.07100250894333926
# EUM6 이상한 숫자   :  1.0058385518511608
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.005838551851160778  ->  -0.07100250894333926
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.00431047998234646
#
# EUM4 이전 투자 금액:  156.672353683404
# EUM5 현재 투자 금액:  168.15952809171114
# EUM5 투자 금액 차이:  0.07331972832628697
# EUM6 이상한 숫자   :  0.9956895200176535
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00431047998234646  ->  0.07331972832628697
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.011547734555798495
#
# EUM4 이전 투자 금액:  509.35749322294924
# EUM5 현재 투자 금액:  500.8117384684314
# EUM5 투자 금액 차이:  -0.016777518478121922
# EUM6 이상한 숫자   :  0.9884522654442015
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.011547734555798495  ->  -0.016777518478121922
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.007604510411542975
#
# EUM4 이전 투자 금액:  178.5531944115316
# EUM5 현재 투자 금액:  182.32695128864842
# EUM5 투자 금액 차이:  0.021135196654163524
# EUM6 이상한 숫자   :  1.007604510411543
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.007604510411542975  ->  0.021135196654163524
# EUM0 현재 날짜 정보:  2017-09-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.01104004230447575
#
# EUM4 이전 투자 금액:  134.34705317266588
# EUM5 현재 투자 금액:  130.91753897682253
# EUM5 투자 금액 차이:  -0.02552727517912634
# EUM6 이상한 숫자   :  0.9889599576955242
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.01104004230447575  ->  -0.02552727517912634
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.00364103999707055
#
# EUM4 이전 투자 금액:  167.3647498928217
# EUM5 현재 투자 금액:  169.09582594611655
# EUM5 투자 금액 차이:  0.010343134109204177
# EUM6 이상한 숫자   :  1.0036410399970705
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.00364103999707055  ->  0.010343134109204177
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.018648982571365602
#
# EUM4 이전 투자 금액:  501.3064705363492
# EUM5 현재 투자 금액:  514.8731992593061
# EUM5 투자 금액 차이:  0.027062744090340374
# EUM6 이상한 숫자   :  1.0186489825713656
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.018648982571365602  ->  0.027062744090340374
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.021052617837016285
#
# EUM4 이전 투자 금액:  185.19373185196835
# EUM5 현재 투자 금액:  176.71647838901376
# EUM5 투자 금액 차이:  -0.04577505608953736
# EUM6 이상한 숫자   :  0.9789473821629837
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.021052617837016285  ->  -0.04577505608953736
# EUM0 현재 날짜 정보:  2017-10-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.005452213500731662
#
# EUM4 이전 투자 금액:  135.17262837876572
# EUM5 현재 투자 금액:  132.690053803038
# EUM5 투자 금액 차이:  -0.018365956225777524
# EUM6 이상한 숫자   :  0.9945477864992683
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.005452213500731662  ->  -0.018365956225777524
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.001111307084843416
#
# EUM4 이전 투자 금액:  165.59920117336492
# EUM5 현재 투자 금액:  169.61535382078014
# EUM5 투자 금액 차이:  0.024252246502147967
# EUM6 이상한 숫자   :  0.9988886929151566
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.001111307084843416  ->  0.024252246502147967
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.006353755035041209
#
# EUM4 이전 투자 금액:  510.9980533165695
# EUM5 현재 투자 금액:  512.648854992007
# EUM5 투자 금액 차이:  0.003230543961416643
# EUM6 이상한 숫자   :  1.0063537550350412
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.006353755035041209  ->  0.003230543961416643
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0035759825122976263
#
# EUM4 이전 투자 금액:  189.1794374706816
# EUM5 현재 투자 금액:  181.28233064021867
# EUM5 투자 금액 차이:  -0.04174400207573714
# EUM6 이상한 숫자   :  0.9964240174877024
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0035759825122976263  ->  -0.04174400207573714
# EUM0 현재 날짜 정보:  2017-11-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.006961910676696825
#
# EUM4 이전 투자 금액:  144.11057745801622
# EUM5 현재 투자 금액:  142.90891281249765
# EUM5 투자 금액 차이:  -0.008338490253213093
# EUM6 이상한 숫자   :  0.9930380893233032
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.006961910676696825  ->  -0.008338490253213093
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.00963760847443118
#
# EUM4 이전 투자 금액:  176.22007383459902
# EUM5 현재 투자 금액:  184.92442564818177
# EUM5 투자 금액 차이:  0.04939478019826904
# EUM6 이상한 숫자   :  1.0096376084744312
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.00963760847443118  ->  0.04939478019826904
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.015064857375860607
#
# EUM4 이전 투자 금액:  547.5215064729615
# EUM5 현재 투자 금액:  541.1998246351723
# EUM5 투자 금액 차이:  -0.011545997304311273
# EUM6 이상한 숫자   :  0.9849351426241394
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.015064857375860607  ->  -0.011545997304311273
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0017406977126365186
#
# EUM4 이전 투자 금액:  186.86614536696905
# EUM5 현재 투자 금액:  195.90041152316547
# EUM5 투자 금액 차이:  0.04834618993427009
# EUM6 이상한 숫자   :  0.9982593022873635
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0017406977126365186  ->  0.04834618993427009
# EUM0 현재 날짜 정보:  2017-12-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.0128771224048283
#
# EUM4 이전 투자 금액:  140.495285259909
# EUM5 현재 투자 금액:  144.498238045395
# EUM5 투자 금액 차이:  0.028491723249507883
# EUM6 이상한 숫자   :  0.9871228775951717
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0128771224048283  ->  0.028491723249507883
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.025122202553130357
#
# EUM4 이전 투자 금액:  188.36876824276868
# EUM5 현재 투자 금액:  190.98634810050373
# EUM5 투자 금액 차이:  0.013896039572555585
# EUM6 이상한 숫자   :  1.0251222025531304
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.025122202553130357  ->  0.013896039572555585
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.015261276269701862
#
# EUM4 이전 투자 금액:  541.5894131010921
# EUM5 현재 투자 금액:  550.3879992355927
# EUM5 투자 금액 차이:  0.016245860649529265
# EUM6 이상한 숫자   :  0.9847387237302981
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.015261276269701862  ->  0.016245860649529265
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.0031911430298301457
#
# EUM4 이전 투자 금액:  214.06149003687793
# EUM5 현재 투자 금액:  200.2504945718974
# EUM5 투자 금액 차이:  -0.06451882336519843
# EUM6 이상한 숫자   :  1.0031911430298301
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0031911430298301457  ->  -0.06451882336519843
# EUM0 현재 날짜 정보:  2018-01-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.003884482335189565
#
# EUM4 이전 투자 금액:  155.8725136377568
# EUM5 현재 투자 금액:  145.28745585347315
# EUM5 투자 금액 차이:  -0.06790843066073238
# EUM6 이상한 숫자   :  1.0038844823351896
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.003884482335189565  ->  -0.06790843066073238
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.0037472924776675853
#
# EUM4 이전 투자 금액:  190.8238082116136
# EUM5 현재 투자 금액:  184.88603765402723
# EUM5 투자 금액 차이:  -0.031116508014564337
# EUM6 이상한 숫자   :  1.0037472924776676
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0037472924776675853  ->  -0.031116508014564337
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.004264490035338797
#
# EUM4 이전 투자 금액:  512.8789772214013
# EUM5 현재 투자 금액:  550.2309028431307
# EUM5 투자 금액 차이:  0.07282795216931892
# EUM6 이상한 숫자   :  0.9957355099646612
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004264490035338797  ->  0.07282795216931892
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.002829286514755225
#
# EUM4 이전 투자 금액:  207.9483913542754
# EUM5 현재 투자 금액:  197.91101229572837
# EUM5 투자 금액 차이:  -0.048268606422863125
# EUM6 이상한 숫자   :  1.0028292865147552
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.002829286514755225  ->  -0.048268606422863125
# EUM0 현재 날짜 정보:  2018-02-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.050759416549253644
#
# EUM4 이전 투자 금액:  148.3953712929104
# EUM5 현재 투자 금액:  139.16287512126306
# EUM5 투자 금액 차이:  -0.06221552661116203
# EUM6 이상한 숫자   :  0.9492405834507464
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.050759416549253644  ->  -0.06221552661116203
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.01936520363001515
#
# EUM4 이전 투자 금액:  174.97190272398691
# EUM5 현재 투자 금액:  182.97415287011938
# EUM5 투자 금액 차이:  0.045734486632152516
# EUM6 이상한 숫자   :  0.9806347963699849
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.01936520363001515  ->  0.045734486632152516
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.010187698496318731
#
# EUM4 이전 투자 금액:  520.4217900562093
# EUM5 현재 투자 금액:  554.0596806430108
# EUM5 투자 금액 차이:  0.06463582276823643
# EUM6 이상한 숫자   :  0.9898123015036813
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.010187698496318731  ->  0.06463582276823643
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0525288132431424
#
# EUM4 이전 투자 금액:  207.75833952470276
# EUM5 현재 투자 금액:  189.41382780909518
# EUM5 투자 금액 차이:  -0.08829735430873709
# EUM6 이상한 숫자   :  0.9474711867568576
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0525288132431424  ->  -0.08829735430873709
# EUM0 현재 날짜 정보:  2018-03-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.14, 0.41, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.009795778196261207
#
# EUM4 이전 투자 금액:  142.01191595575264
# EUM5 현재 투자 금액:  165.76060481714472
# EUM5 투자 금액 차이:  0.16723025459913932
# EUM6 이상한 숫자   :  1.0097957781962612
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.009795778196261207  ->  0.16723025459913932
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.0010539809850911297
#
# EUM4 이전 투자 금액:  191.5015054643911
# EUM5 현재 투자 금액:  191.71321873182745
# EUM5 투자 금액 차이:  0.0011055436192157764
# EUM6 이상한 숫자   :  1.0010539809850911
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0010539809850911297  ->  0.0011055436192157764
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.01447978514802406
#
# EUM4 이전 투자 금액:  567.5297162047865
# EUM5 현재 투자 금액:  568.975780554398
# EUM5 투자 금액 차이:  0.002547997590825357
# EUM6 이상한 숫자   :  1.014479785148024
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.01447978514802406  ->  0.002547997590825357
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.010440295417046164
#
# EUM4 이전 투자 금액:  215.20304042094017
# EUM5 현재 투자 금액:  207.33300499523233
# EUM5 투자 금액 차이:  -0.036570279910144166
# EUM6 이상한 숫자   :  1.0104402954170462
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.010440295417046164  ->  -0.036570279910144166
# EUM0 현재 날짜 정보:  2018-04-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.41, 0.16]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.010827706778402613
#
# EUM4 이전 투자 금액:  154.24112151960344
# EUM5 현재 투자 금액:  147.9959875642507
# EUM5 투자 금액 차이:  -0.04048942262494515
# EUM6 이상한 숫자   :  1.0108277067784026
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.010827706778402613  ->  -0.04048942262494515
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.014310430622009651
#
# EUM4 이전 투자 금액:  195.1108462494832
# EUM5 현재 투자 금액:  189.00750347102024
# EUM5 투자 금액 차이:  -0.03128141205773238
# EUM6 이상한 숫자   :  1.0143104306220097
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.014310430622009651  ->  -0.03128141205773238
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.014036808594114936
#
# EUM4 이전 투자 금액:  560.4739849136605
# EUM5 현재 투자 금액:  553.372655464703
# EUM5 투자 금액 차이:  -0.012670221348545563
# EUM6 이상한 숫자   :  1.014036808594115
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.014036808594114936  ->  -0.012670221348545563
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.003653944197953285
#
# EUM4 이전 투자 금액:  192.7098102338519
# EUM5 현재 투자 금액:  213.73915926633845
# EUM5 투자 금액 차이:  0.10912443433454477
# EUM6 이상한 숫자   :  1.0036539441979533
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.003653944197953285  ->  0.10912443433454477
# EUM0 현재 날짜 정보:  2018-05-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.41, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.024066988206888018
#
# EUM4 이전 투자 금액:  147.50589488837252
# EUM5 현재 투자 금액:  157.76111184311839
# EUM5 투자 금액 차이:  0.06952411605316966
# EUM6 이상한 숫자   :  1.024066988206888
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.024066988206888018  ->  0.06952411605316966
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.02761443292652488
#
# EUM4 이전 투자 금액:  180.3330021388371
# EUM5 현재 투자 금액:  201.482410367902
# EUM5 투자 금액 차이:  0.11727974346471615
# EUM6 이상한 숫자   :  1.0276144329265249
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.02761443292652488  ->  0.11727974346471615
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.004972082686867441
#
# EUM4 이전 투자 금액:  571.5342836469307
# EUM5 현재 투자 금액:  571.3444713958235
# EUM5 투자 금액 차이:  -0.00033211000028909865
# EUM6 이상한 숫자   :  0.9950279173131326
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004972082686867441  ->  -0.00033211000028909865
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.01935191514143564
#
# EUM4 이전 투자 금액:  230.54776361836613
# EUM5 현재 투자 금액:  214.13827949652065
# EUM5 투자 금액 차이:  -0.07117607156237127
# EUM6 이상한 숫자   :  1.0193519151414356
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.01935191514143564  ->  -0.07117607156237127
# EUM0 현재 날짜 정보:  2018-06-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.1, 0.14, 0.42, 0.16]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.015894307544052966
#
# EUM4 이전 투자 금액:  170.36999233295847
# EUM5 현재 투자 금액:  141.82852025890654
# EUM5 투자 금액 차이:  -0.16752640346589087
# EUM6 이상한 숫자   :  1.015894307544053
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.015894307544052966  ->  -0.16752640346589087
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.0028114422914160553
#
# EUM4 이전 투자 금액:  199.83223829490709
# EUM5 현재 투자 금액:  196.0028387439443
# EUM5 투자 금액 차이:  -0.01916307190290023
# EUM6 이상한 숫자   :  1.002811442291416
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0028114422914160553  ->  -0.01916307190290023
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.006108740389497269
#
# EUM4 이전 투자 금액:  556.2814973906395
# EUM5 현재 투자 금액:  582.7780779245718
# EUM5 투자 금액 차이:  0.047631604966586805
# EUM6 이상한 숫자   :  0.9938912596105027
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.006108740389497269  ->  0.047631604966586805
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0018322664833739788
#
# EUM4 이전 투자 금액:  206.38582438862107
# EUM5 현재 투자 금액:  222.96595472746765
# EUM5 투자 금액 차이:  0.08033560632355474
# EUM6 이상한 숫자   :  0.998167733516626
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0018322664833739788  ->  0.08033560632355474
# EUM0 현재 날짜 정보:  2018-07-05 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.14, 0.41, 0.16]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.0224047811563719
#
# EUM4 이전 투자 금액:  137.3068925502968
# EUM5 현재 투자 금액:  158.11849471290898
# EUM5 투자 금액 차이:  0.15156997420933327
# EUM6 이상한 숫자   :  1.022404781156372
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0224047811563719  ->  0.15156997420933327
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.003280688080789629
#
# EUM4 이전 투자 금액:  167.49710816739295
# EUM5 현재 투자 금액:  196.18600472788583
# EUM5 투자 금액 차이:  0.17127995148323283
# EUM6 이상한 숫자   :  0.9967193119192104
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.003280688080789629  ->  0.17127995148323283
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.011914957941542959
#
# EUM4 이전 투자 금액:  623.5049485610296
# EUM5 현재 투자 금액:  583.3040430243158
# EUM5 투자 금액 차이:  -0.0644756799917825
# EUM6 이상한 숫자   :  1.011914957941543
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.011914957941542959  ->  -0.0644756799917825
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.005195890713992624
#
# EUM4 이전 투자 금액:  218.31020045153596
# EUM5 현재 투자 금액:  226.11938805903128
# EUM5 투자 금액 차이:  0.035771061504883406
# EUM6 이상한 숫자   :  1.0051958907139926
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.005195890713992624  ->  0.035771061504883406
# EUM0 현재 날짜 정보:  2018-08-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.13, 0.42, 0.16]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.00039574063194469655
#
# EUM4 이전 투자 금액:  171.53921800543722
# EUM5 현재 투자 금액:  162.99795452728003
# EUM5 투자 금액 차이:  -0.049791899353805236
# EUM6 이상한 숫자   :  0.9996042593680553
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00039574063194469655  ->  -0.049791899353805236
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.0030632811582222974
#
# EUM4 이전 투자 금액:  210.79598339886917
# EUM5 현재 투자 금액:  192.11988396579176
# EUM5 투자 금액 차이:  -0.08859798527440821
# EUM6 이상한 숫자   :  0.9969367188417777
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0030632811582222974  ->  -0.08859798527440821
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.0012264351887685265
#
# EUM4 이전 투자 금액:  600.1064904224937
# EUM5 현재 투자 금액:  623.3657966365848
# EUM5 투자 금액 차이:  0.03875863131844448
# EUM6 이상한 숫자   :  1.0012264351887685
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0012264351887685265  ->  0.03875863131844448
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.01097367629981938
#
# EUM4 이전 투자 금액:  227.55385905674382
# EUM5 현재 투자 금액:  239.7845525889832
# EUM5 투자 금액 차이:  0.05374856564919628
# EUM6 이상한 숫자   :  1.0109736762998194
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.01097367629981938  ->  0.05374856564919628
# EUM0 현재 날짜 정보:  2018-09-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.11, 0.13, 0.42, 0.15]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.016634185275336
#
# EUM4 이전 투자 금액:  162.22489130104512
# EUM5 현재 투자 금액:  160.53506643905502
# EUM5 투자 금액 차이:  -0.010416557215342848
# EUM6 이상한 숫자   :  0.983365814724664
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.016634185275336  ->  -0.010416557215342848
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.001496778144383093
#
# EUM4 이전 투자 금액:  198.58454438012586
# EUM5 현재 투자 금액:  193.22131308766254
# EUM5 투자 금액 차이:  -0.02700729459689044
# EUM6 이상한 숫자   :  1.001496778144383
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.001496778144383093  ->  -0.02700729459689044
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.002512849272182649
#
# EUM4 이전 투자 금액:  564.19848940196
# EUM5 현재 투자 금액:  624.8868110164228
# EUM5 투자 금액 차이:  0.10756555140512924
# EUM6 이상한 숫자   :  1.0025128492721826
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.002512849272182649  ->  0.10756555140512924
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.0008375483663873862
#
# EUM4 이전 투자 금액:  264.5383109028247
# EUM5 현재 투자 금액:  222.42801410118105
# EUM5 투자 금액 차이:  -0.1591841146105769
# EUM6 이상한 숫자   :  0.9991624516336126
# --------------------------------------------------------------
# ...
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.009568404916545648
#
# EUM4 이전 투자 금액:  314.44415632898415
# EUM5 현재 투자 금액:  323.47443242762046
# EUM5 투자 금액 차이:  0.02871821885342496
# EUM6 이상한 숫자   :  1.0095684049165456
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.009568404916545648  ->  0.02871821885342496
# EUM0 현재 날짜 정보:  2019-12-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.12, 0.41, 0.17]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.018690973751026574
#
# EUM4 이전 투자 금액:  230.16889681867156
# EUM5 현재 투자 금액:  229.89190642187262
# EUM5 투자 금액 차이:  -0.0012034223590912108
# EUM6 이상한 숫자   :  1.0186909737510266
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.018690973751026574  ->  -0.0012034223590912108
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.006838053456271309
#
# EUM4 이전 투자 금액:  231.69929846399145
# EUM5 현재 투자 금액:  227.21701235346424
# EUM5 투자 금액 차이:  -0.019345272688530812
# EUM6 이상한 숫자   :  1.0068380534562713
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.006838053456271309  ->  -0.019345272688530812
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.005130598235374428
#
# EUM4 이전 투자 금액:  781.8854922749474
# EUM5 현재 투자 금액:  775.008254940314
# EUM5 투자 금액 차이:  -0.00879570909369809
# EUM6 이상한 숫자   :  1.0051305982353744
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.005130598235374428  ->  -0.00879570909369809
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.008807641083101059
#
# EUM4 이전 투자 금액:  301.67326593937275
# EUM5 현재 투자 금액:  316.8887668253867
# EUM5 투자 금액 차이:  0.050437021121625625
# EUM6 이상한 숫자   :  0.9911923589168989
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.008807641083101059  ->  0.050437021121625625
# EUM0 현재 날짜 정보:  2020-01-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.12, 0.41, 0.17]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.026654062035014414
#
# EUM4 이전 투자 금액:  237.31363581867262
# EUM5 현재 투자 금액:  240.49231836051928
# EUM5 투자 금액 차이:  0.01339443699002385
# EUM6 이상한 숫자   :  1.0266540620350144
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.026654062035014414  ->  0.01339443699002385
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.007880278878263147
#
# EUM4 이전 투자 금액:  236.34296211988135
# EUM5 현재 투자 금액:  232.40269594883353
# EUM5 투자 금액 차이:  -0.016671815127074496
# EUM6 이상한 숫자   :  0.9921197211217369
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.007880278878263147  ->  -0.016671815127074496
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.0039961401482986325
#
# EUM4 이전 투자 금액:  773.4011878947802
# EUM5 현재 투자 금액:  803.547830781934
# EUM5 투자 금액 차이:  0.03897930771119418
# EUM6 이상한 숫자   :  1.0039961401482986
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0039961401482986325  ->  0.03897930771119418
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.0035691320734296816
#
# EUM4 이전 투자 금액:  346.41993935665715
# EUM5 현재 투자 금액:  333.03666527431784
# EUM5 투자 금액 차이:  -0.03863309400490522
# EUM6 이상한 숫자   :  1.0035691320734297
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.0035691320734296816  ->  -0.03863309400490522
# EUM0 현재 날짜 정보:  2020-02-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.12, 0.41, 0.17]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.025084272237055893
#
# EUM4 이전 투자 금액:  255.0803688511285
# EUM5 현재 투자 금액:  244.0594646100697
# EUM5 투자 금액 차이:  -0.04320561511925236
# EUM6 이상한 숫자   :  0.9749157277629441
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.025084272237055893  ->  -0.04320561511925236
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.027554908063243788
#
# EUM4 이전 투자 금액:  226.81217187230115
# EUM5 현재 투자 금액:  257.237106323865
# EUM5 투자 금액 차이:  0.13414154187762728
# EUM6 이상한 숫자   :  1.0275549080632438
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.027554908063243788  ->  0.13414154187762728
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.016407381300375445
#
# EUM4 이전 투자 금액:  904.4870001435809
# EUM5 현재 투자 금액:  841.2913995370237
# EUM5 투자 금액 차이:  -0.06986899822388304
# EUM6 이상한 숫자   :  0.9835926186996246
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.016407381300375445  ->  -0.06986899822388304
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.02342581116527498
#
# EUM4 이전 투자 금액:  324.1881957099708
# EUM5 현재 투자 금액:  362.9548622578983
# EUM5 투자 금액 차이:  0.11958074680365427
# EUM6 이상한 숫자   :  1.023425811165275
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.02342581116527498  ->  0.11958074680365427
# EUM0 현재 날짜 정보:  2020-03-04 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.12, 0.42, 0.17]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.03280208552149255
#
# EUM4 이전 투자 금액:  225.87584984719683
# EUM5 현재 투자 금액:  235.30263310666336
# EUM5 투자 금액 차이:  0.04173435657616187
# EUM6 이상한 숫자   :  1.0328020855214926
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.03280208552149255  ->  0.04173435657616187
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.01361309338742589
#
# EUM4 이전 투자 금액:  229.83785860807075
# EUM5 현재 투자 금액:  230.9308174034359
# EUM5 투자 금액 차이:  0.004755347104190122
# EUM6 이상한 숫자   :  1.013613093387426
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.01361309338742589  ->  0.004755347104190122
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.06103283776367818
#
# EUM4 이전 투자 금액:  780.0134521494263
# EUM5 현재 투자 금액:  846.0704951455251
# EUM5 투자 금액 차이:  0.08468705611944283
# EUM6 이상한 숫자   :  1.0610328377636782
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.06103283776367818  ->  0.08468705611944283
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.03371632336999664
#
# EUM4 이전 투자 금액:  305.1808597418159
# EUM5 현재 투자 금액:  333.64047471198995
# EUM5 투자 금액 차이:  0.09325491446039913
# EUM6 이상한 숫자   :  1.0337163233699966
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.03371632336999664  ->  0.09325491446039913
# EUM0 현재 날짜 정보:  2020-04-06 00:00:00
# EUM2 현재 weight:  [0.18, 0.12, 0.12, 0.41, 0.16]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.08281320973550721
#
# EUM4 이전 투자 금액:  186.099580377614
# EUM5 현재 투자 금액:  215.08945904728014
# EUM5 투자 금액 차이:  0.15577616355094892
# EUM6 이상한 숫자   :  1.0828132097355072
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.08281320973550721  ->  0.15577616355094892
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.075178347326047
#
# EUM4 이전 투자 금액:  182.75624662797955
# EUM5 현재 투자 금액:  213.57287390518317
# EUM5 투자 금액 차이:  0.16862147174610276
# EUM6 이상한 숫자   :  1.075178347326047
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.075178347326047  ->  0.16862147174610276
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.1020490611340723
#
# EUM4 이전 투자 금액:  627.3150303693827
# EUM5 현재 투자 금액:  747.9440671406616
# EUM5 투자 금액 차이:  0.19229419180383522
# EUM6 이상한 숫자   :  1.1020490611340723
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.1020490611340723  ->  0.19229419180383522
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.060675917514241506
#
# EUM4 이전 투자 금액:  317.8438052667246
# EUM5 현재 투자 금액:  280.9228249420689
# EUM5 투자 금액 차이:  -0.116160767373373
# EUM6 이상한 숫자   :  1.0606759175142415
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.060675917514241506  ->  -0.116160767373373
# EUM0 현재 날짜 정보:  2020-05-04 00:00:00
# EUM2 현재 weight:  [0.19, 0.1, 0.11, 0.39, 0.2]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.004235932311447366
#
# EUM4 이전 투자 금액:  239.47265331105513
# EUM5 현재 투자 금액:  184.9050087297574
# EUM5 투자 금액 차이:  -0.2278658703898807
# EUM6 이상한 숫자   :  1.0042359323114474
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.004235932311447366  ->  -0.2278658703898807
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.025748792818546584
#
# EUM4 이전 투자 금액:  232.4759365648453
# EUM5 현재 투자 금액:  197.32247611340608
# EUM5 투자 금액 차이:  -0.15121332973588753
# EUM6 이상한 숫자   :  0.9742512071814534
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.025748792818546584  ->  -0.15121332973588753
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.009373233822585147
#
# EUM4 이전 투자 금액:  734.578260085507
# EUM5 현재 투자 금액:  724.818567395472
# EUM5 투자 금액 차이:  -0.01328611697397497
# EUM6 이상한 숫자   :  1.0093732338225851
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.009373233822585147  ->  -0.01328611697397497
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.010508334107731887
#
# EUM4 이전 투자 금액:  277.4646658529031
# EUM5 현재 투자 금액:  372.119830266609
# EUM5 투자 금액 차이:  0.34114312942422353
# EUM6 이상한 숫자   :  1.0105083341077319
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.010508334107731887  ->  0.34114312942422353
# EUM0 현재 날짜 정보:  2020-06-04 00:00:00
# EUM2 현재 weight:  [0.19, 0.11, 0.12, 0.39, 0.19]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.01733538382621158
#
# EUM4 이전 투자 금액:  201.16753261999128
# EUM5 현재 투자 금액:  216.89259942698342
# EUM5 투자 금액 차이:  0.0781690096915244
# EUM6 이상한 숫자   :  0.9826646161737884
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.01733538382621158  ->  0.0781690096915244
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.010555526824337136
#
# EUM4 이전 투자 금액:  219.6642894968553
# EUM5 현재 투자 금액:  238.24259087555893
# EUM5 투자 금액 차이:  0.08457588359608903
# EUM6 이상한 숫자   :  0.9894444731756629
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.010555526824337136  ->  0.08457588359608903
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.01294494663821344
#
# EUM4 이전 투자 금액:  784.0024970078775
# EUM5 현재 투자 금액:  772.41858313551
# EUM5 투자 금액 차이:  -0.01477535328851276
# EUM6 이상한 숫자   :  0.9870550533617866
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.01294494663821344  ->  -0.01477535328851276
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.001704266982925029
#
# EUM4 이전 투자 금액:  422.4257663834849
# EUM5 현재 투자 금액:  380.59190438806553
# EUM5 투자 금액 차이:  -0.09903245806611605
# EUM6 이상한 숫자   :  0.998295733017075
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.001704266982925029  ->  -0.09903245806611605
# EUM0 현재 날짜 정보:  2020-07-06 00:00:00
# EUM2 현재 weight:  [0.19, 0.12, 0.12, 0.39, 0.19]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.020218629198100135
#
# EUM4 이전 투자 금액:  225.42384170132723
# EUM5 현재 투자 금액:  241.23154381336946
# EUM5 투자 금액 차이:  0.07012435771095782
# EUM6 이상한 숫자   :  1.0202186291981001
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.020218629198100135  ->  0.07012435771095782
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.02249925049853596
#
# EUM4 이전 투자 금액:  223.23520634464404
# EUM5 현재 투자 금액:  241.77079861759725
# EUM5 투자 금액 차이:  0.08303167128726474
# EUM6 이상한 숫자   :  1.022499250498536
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.02249925049853596  ->  0.08303167128726474
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.003409806309884633
#
# EUM4 이전 투자 금액:  703.640703611527
# EUM5 현재 투자 금액:  765.8448868717561
# EUM5 투자 금액 차이:  0.08840333275343237
# EUM6 이상한 숫자   :  0.9965901936901154
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.003409806309884633  ->  0.08840333275343237
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.017313166573702965
#
# EUM4 이전 투자 금액:  373.5213720165655
# EUM5 현재 투자 금액:  380.8621958670724
# EUM5 투자 금액 차이:  0.01965302229126875
# EUM6 이상한 숫자   :  1.017313166573703
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.017313166573702965  ->  0.01965302229126875
# EUM0 현재 날짜 정보:  2020-08-04 00:00:00
# EUM2 현재 weight:  [0.19, 0.12, 0.12, 0.39, 0.19]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.0063799676786503445
#
# EUM4 이전 투자 금액:  238.51464037433877
# EUM5 현재 투자 금액:  245.23168277297356
# EUM5 투자 금액 차이:  0.02816197105591778
# EUM6 이상한 숫자   :  0.9936200323213497
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0063799676786503445  ->  0.02816197105591778
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.004900776852090227
#
# EUM4 이전 투자 금액:  241.96311037039123
# EUM5 현재 투자 금액:  245.59675638636702
# EUM5 투자 금액 차이:  0.01501735537460025
# EUM6 이상한 숫자   :  0.9950992231479098
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.004900776852090227  ->  0.01501735537460025
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.00796149135319002
#
# EUM4 이전 투자 금액:  786.2247115978447
# EUM5 현재 투자 금액:  808.5065468955924
# EUM5 투자 금액 차이:  0.028340288684725046
# EUM6 이상한 숫자   :  1.00796149135319
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.00796149135319002  ->  0.028340288684725046
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.010814202834284359
#
# EUM4 이전 투자 금액:  386.93368542970956
# EUM5 현재 투자 금액:  395.00257790548676
# EUM5 투자 금액 차이:  0.020853424707172552
# EUM6 이상한 숫자   :  1.0108142028342844
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.010814202834284359  ->  0.020853424707172552
# EUM0 현재 날짜 정보:  2020-09-04 00:00:00
# EUM2 현재 weight:  [0.19, 0.11, 0.12, 0.39, 0.19]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  -0.029640842055994487
#
# EUM4 이전 투자 금액:  271.2329250976948
# EUM5 현재 투자 금액:  225.01785860204916
# EUM5 투자 금액 차이:  -0.17038885112859936
# EUM6 이상한 숫자   :  0.9703591579440055
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.029640842055994487  ->  -0.17038885112859936
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  -0.0024284015104892864
#
# EUM4 이전 투자 금액:  284.2372699281446
# EUM5 현재 투자 금액:  252.3580223485412
# EUM5 투자 금액 차이:  -0.11215716921170293
# EUM6 이상한 숫자   :  0.9975715984895107
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.0024284015104892864  ->  -0.11215716921170293
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  -0.00589347394739459
#
# EUM4 이전 투자 금액:  790.3754737336683
# EUM5 현재 투자 금액:  817.3147283056082
# EUM5 투자 금액 차이:  0.034084122631843794
# EUM6 이상한 숫자   :  0.9941065260526054
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.00589347394739459  ->  0.034084122631843794
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  -0.003174672416827451
#
# EUM4 이전 투자 금액:  339.3194163374392
# EUM5 현재 투자 금액:  399.26795771332576
# EUM5 투자 금액 차이:  0.17667288840397566
# EUM6 이상한 숫자   :  0.9968253275831725
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  -0.003174672416827451  ->  0.17667288840397566
# EUM0 현재 날짜 정보:  2020-10-05 00:00:00
# EUM2 현재 weight:  [0.19, 0.12, 0.12, 0.39, 0.19]
# EUM9 현재 주식 번호:  0
# EUM9 현재 주식 번호:  1
# EUM3 주식 가격 차이:  0.018707049275532572
#
# EUM4 이전 투자 금액:  207.14262974497484
# EUM5 현재 투자 금액:  255.38965900928213
# EUM5 투자 금액 차이:  0.2329169486923428
# EUM6 이상한 숫자   :  1.0187070492755326
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.018707049275532572  ->  0.2329169486923428
# EUM9 현재 주식 번호:  2
# EUM3 주식 가격 차이:  0.02194755848597363
#
# EUM4 이전 투자 금액:  253.23560727037923
# EUM5 현재 투자 금액:  256.20205403772485
# EUM5 투자 금액 차이:  0.011714177162212236
# EUM6 이상한 숫자   :  1.0219475584859736
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.02194755848597363  ->  0.011714177162212236
# EUM9 현재 주식 번호:  3
# EUM3 주식 가격 차이:  0.016174937107969356
#
# EUM4 이전 투자 금액:  879.3674445658233
# EUM5 현재 투자 금액:  827.9532916903049
# EUM5 투자 금액 차이:  -0.05846720070573397
# EUM6 이상한 숫자   :  1.0161749371079694
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.016174937107969356  ->  -0.05846720070573397
# EUM9 현재 주식 번호:  4
# EUM3 주식 가격 차이:  0.007839018381816887
#
# EUM4 이전 투자 금액:  377.7786089150415
# EUM5 현재 투자 금액:  400.0529891503777
# EUM5 투자 금액 차이:  0.05896146502129107
# EUM6 이상한 숫자   :  1.0078390183818169
# --------------------------------------------------------------
# EUM7 수익률 업데이트:  0.007839018381816887  ->  0.05896146502129107
# Portfolio Backtest Complete
# Total Complete
# AMZN Complete
# GOOGL Complete
# SBUX Complete
# SO Complete
# CSCO Complete
# Annual Result Complete
# Monthly Result Complete
# ['AMZN (19%, 1x) GOOGL (12%, 1x) SBUX (12%, 1x) SO (39%, 1x) CSCO (19%, 1x) ',
#  1000.0,
#  2120.1971401583705,
#  '16.86%',
#  '-29.49%',
#  1.23,
#  0.9]

# %% [markdown]
# ### 2) GMV - Efficient Frontier

# %%
# GMV.display_calculated_ef_with_random()
# GMV.display_ef_with_selected()
GMV.display_ef_with_selected_and_random()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-cfd953b3c1e9> in <module>()
#       1 # GMV.display_calculated_ef_with_random()
#       2 # GMV.display_ef_with_selected()
# ----> 3 GMV.display_ef_with_selected_and_random()
#
# <ipython-input-9-edf02e0bab0f> in display_ef_with_selected_and_random(self)
#     171         max_sharpe = self.max_sharpe_ratio()
#     172         sdp, rp = self.portfolio_annualised_performance(max_sharpe['x'], self.mean_returns, self.cov_matrix)
# --> 173         max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=df.columns,columns=['allocation'])
#     174         max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
#     175         max_sharpe_allocation = max_sharpe_allocation.T
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. 60/40 Portfolio

# %%
asset1 = Asset('^IXIC', 'Asset 1', '2016-01-01', '2020-10-31')
asset2 = Asset('VUSTX', 'Asset 2', '2016-01-01', '2020-10-31')

sixty_forty_portfolio = Portfolio('60/40', [asset1, asset2], [6, 4], [1, 1], 1000, 3)
sixty_forty_backtest_df = sixty_forty_portfolio.backtest()
sixty_forty_backtest_result_df = sixty_forty_portfolio.backtest_result()
sixty_forty_annual_return_df = sixty_forty_portfolio.periodic_result('annual')
sixty_forty_monthly_return_df = sixty_forty_portfolio.periodic_result('monthly')
sixty_forty_summary = sixty_forty_portfolio.get_summary()
# Out:
# EUM1 : 1013.0771185189658
# EUM2 : 0.6
# EUM3 : 1.0001150185323233
# EUM1 : 1013.0771185189658
# EUM2 : 0.4
# EUM3 : 1.008383548272043
# EUM1 : 1030.1979352903948
# EUM2 : 0.6
# EUM3 : 1.0132698481717843
# EUM1 : 1030.1979352903948
# EUM2 : 0.4
# EUM3 : 1.0049199204104486
# EUM1 : 1096.4100387432372
# EUM2 : 0.6
# EUM3 : 1.008132260127424
# EUM1 : 1096.4100387432372
# EUM2 : 0.4
# EUM3 : 0.9946505827494936
# EUM1 : 1059.5700139552075
# EUM2 : 0.6
# EUM3 : 0.9909851037131053
# EUM1 : 1059.5700139552075
# EUM2 : 0.4
# EUM3 : 1.0058259046294769
# EUM1 : 1124.5610921285013
# EUM2 : 0.6
# EUM3 : 1.0028469516356022
# EUM1 : 1124.5610921285013
# EUM2 : 0.4
# EUM3 : 0.9924431577229889
# EUM1 : 1170.1170465121581
# EUM2 : 0.6
# EUM3 : 0.999360359400297
# EUM1 : 1170.1170465121581
# EUM2 : 0.4
# EUM3 : 0.9989387282880854
# EUM1 : 1211.3598150582675
# EUM2 : 0.6
# EUM3 : 1.003195871592665
# EUM1 : 1211.3598150582675
# EUM2 : 0.4
# EUM3 : 0.9983608274734843
# EUM1 : 1268.6760274865424
# EUM2 : 0.6
# EUM3 : 1.0149940483697186
# EUM1 : 1268.6760274865424
# EUM2 : 0.4
# EUM3 : 0.9887188048040048
# EUM1 : 1268.0573629139467
# EUM2 : 0.6
# EUM3 : 0.972629512096893
# EUM1 : 1268.0573629139467
# EUM2 : 0.4
# EUM3 : 1.0008418131487842
# EUM1 : 1318.111171029943
# EUM2 : 0.6
# EUM3 : 1.007641524068444
# EUM1 : 1318.111171029943
# EUM2 : 0.4
# EUM3 : 0.99915542010269
# EUM1 : 1359.5075184062403
# EUM2 : 0.6
# EUM3 : 0.9988752300286579
# EUM1 : 1359.5075184062403
# EUM2 : 0.4
# EUM3 : 0.9929946971390586
# EUM1 : 1232.2372462581236
# EUM2 : 0.6
# EUM3 : 1.0077089545592441
# EUM1 : 1232.2372462581236
# EUM2 : 0.4
# EUM3 : 1.0050124519283155
# EUM1 : 1386.065395999197
# EUM2 : 0.6
# EUM3 : 1.0128847472088292
# EUM1 : 1386.065395999197
# EUM2 : 0.4
# EUM3 : 0.9853539392260728
# EUM1 : 1447.4966525004156
# EUM2 : 0.6
# EUM3 : 1.0106067166846173
# EUM1 : 1447.4966525004156
# EUM2 : 0.4
# EUM3 : 0.9976741718194426
# EUM1 : 1484.1036927082444
# EUM2 : 0.6
# EUM3 : 1.007520496776148
# EUM1 : 1484.1036927082444
# EUM2 : 0.4
# EUM3 : 1.0041326328485058
# EUM1 : 1585.4987712387733
# EUM2 : 0.6
# EUM3 : 0.9932682979826363
# EUM1 : 1585.4987712387733
# EUM2 : 0.4
# EUM3 : 0.9962350131834237
# EUM1 : 1558.4759403190646
# EUM2 : 0.6
# EUM3 : 1.036224507926326
# EUM1 : 1558.4759403190646
# EUM2 : 0.4
# EUM3 : 0.9949844336286339
# EUM1 : 1853.171674282462
# EUM2 : 0.6
# EUM3 : 1.0186972178183844
# EUM1 : 1853.171674282462
# EUM2 : 0.4
# EUM3 : 0.9970058725813907
# EUM1 : 1993.271854615191
# EUM2 : 0.6
# EUM3 : 1.0074206504702194
# EUM1 : 1993.271854615191
# EUM2 : 0.4
# EUM3 : 0.9924879573660937
# Portfolio Backtest Complete
# Total Complete
# Asset 1 Complete
# Asset 2 Complete
# Annual Result Complete
# Monthly Result Complete

# %%
sixty_forty_summary
# Out:
# ['Asset 1 (60%, 1x) Asset 2 (40%, 1x) ',
#  1000.0,
#  1943.2611274026767,
#  '14.73%',
#  '-17.18%',
#  0.73,
#  1.24]

# %% [markdown]
# ## 4. All Weather Portfolio

# %%
asset3 = Asset('VTI', 'Asset 3', '2016-01-01', '2020-10-31')
asset4 = Asset('EDV', 'Asset 4', '2016-01-01', '2020-10-31')
asset5 = Asset('IEI', 'Asset 5', '2016-01-01', '2020-10-31')
asset6 = Asset('GLD', 'Asset 6', '2016-01-01', '2020-10-31')
asset7 = Asset('GSG', 'Asset 7', '2016-01-01', '2020-10-31')

awf_portfolio = Portfolio('All Weather', [asset3, asset4, asset5, asset6, asset7], [3, 4, 1.5, 0.75, 0.75], [1, 1, 1, 1, 1], 1000, 12)
awf_backtest_df = awf_portfolio.backtest()
awf_backtest_result_df = awf_portfolio.backtest_result()
awf_annual_return_df = awf_portfolio.periodic_result('annual')
awf_monthly_return_df = awf_portfolio.periodic_result('monthly')
awf_summary = awf_portfolio.get_summary()
# Out:
# Portfolio Backtest Complete
# Total Complete
# Asset 3 Complete
# Asset 4 Complete
# Asset 5 Complete
# Asset 6 Complete
# Asset 7 Complete
# Annual Result Complete
# Monthly Result Complete

# %%
awf_summary
# Out:
# ['Asset 3 (30%, 1x) Asset 4 (40%, 1x) Asset 5 (15%, 1x) Asset 6 (7%, 1x) Asset 7 (7%, 1x) ',
#  1000.0,
#  1527.8005406978286,
#  '9.16%',
#  '-14.58%',
#  0.52,
#  1.1]

# %% [markdown]
# ## 5. Result Visualization

# %%
aw_64 = Visualize([gmv_portfolio, sixty_forty_portfolio, awf_portfolio])

# %%
aw_64.line_plot('Drawdown', 'GMV VS 60/40 VS All Weather Drawdown', 'linear')
# Out:
# <div>                            <div id="766c9902-462c-4546-b3a4-c694f1137078" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("766c9902-462c-4546-b3a4-c694f1137078")) {                    Plotly.newPlot(                        "766c9902-462c-4546-b3a4-c694f1137078",                        [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "GMV", "text": "", "type": "scatter", "x": ["2015-12-31", "2016-01-04", "2016-01-05", "2016-01-06", "2016-01-07", "2016-01-08", "2016-01-11", "2016-01-12", "2016-01-13", "2016-01-14", "2016-01-15", "2016-01-19", "2016-01-20", "2016-01-21", "2016-01-22", "2016-01-25", "2016-01-26", "2016-01-27", "2016-01-28", "2016-01-29", "2016-02-01", "2016-02-02", "2016-02-03", "2016-02-04", "2016-02-05", "2016-02-08", "2016-02-09", "2016-02-10", "2016-02-11", "2016-02-12", "2016-02-16", "2016-02-17", "2016-02-18", "2016-02-19", "2016-02-22", "2016-02-23", "2016-02-24", "2016-02-25", "2016-02-26", "2016-02-29", "2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-07", "2016-03-08", "2016-03-09", "2016-03-10", "2016-03-11", "2016-03-14", "2016-03-15", "2016-03-16", "2016-03-17", "2016-03-18", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-24", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-14", "2016-04-15", "2016-04-18", "2016-04-19", "2016-04-20", "2016-04-21", "2016-04-22", "2016-04-25", "2016-04-26", "2016-04-27", "2016-04-28", "2016-04-29", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-05", "2016-05-06", "2016-05-09", "2016-05-10", "2016-05-11", "2016-05-12", "2016-05-13", "2016-05-16", "2016-05-17", "2016-05-18", "2016-05-19", "2016-05-20", "2016-05-23", "2016-05-24", "2016-05-25", "2016-05-26", "2016-05-27", "2016-05-31", "2016-06-01", "2016-06-02", "2016-06-03", "2016-06-06", "2016-06-07", "2016-06-08", "2016-06-09", "2016-06-10", "2016-06-13", "2016-06-14", "2016-06-15", "2016-06-16", "2016-06-17", "2016-06-20", "2016-06-21", "2016-06-22", "2016-06-23", "2016-06-24", "2016-06-27", "2016-06-28", "2016-06-29", "2016-06-30", "2016-07-01", "2016-07-05", "2016-07-06", "2016-07-07", "2016-07-08", "2016-07-11", "2016-07-12", "2016-07-13", "2016-07-14", "2016-07-15", "2016-07-18", "2016-07-19", "2016-07-20", "2016-07-21", "2016-07-22", "2016-07-25", "2016-07-26", "2016-07-27", "2016-07-28", "2016-07-29", "2016-08-01", "2016-08-02", "2016-08-03", "2016-08-04", "2016-08-05", "2016-08-08", "2016-08-09", "2016-08-10", "2016-08-11", "2016-08-12", "2016-08-15", "2016-08-16", "2016-08-17", "2016-08-18", "2016-08-19", "2016-08-22", "2016-08-23", "2016-08-24", "2016-08-25", "2016-08-26", "2016-08-29", "2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-25", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", ...

# %%
aw_64.bar_plot('GMV VS 60/40 VS All Weather Monthly Return', 'monthly')
# Out:
# Monthly Result Complete
# Monthly Result Complete
# Monthly Result Complete
# <div>                            <div id="477cf025-5117-4f22-80a3-d8f736d3ec1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("477cf025-5117-4f22-80a3-d8f736d3ec1c")) {                    Plotly.newPlot(                        "477cf025-5117-4f22-80a3-d8f736d3ec1c",                        [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "GMV", "orientation": "v", "text": "", "type": "bar", "x": ["2015-12", "2016-01", "2016-02", "2016-03", "2016-04", "2016-05", "2016-06", "2016-07", "2016-08", "2016-09", "2016-10", "2016-11", "2016-12", "2017-01", "2017-02", "2017-03", "2017-04", "2017-05", "2017-06", "2017-07", "2017-08", "2017-09", "2017-10", "2017-11", "2017-12", "2018-01", "2018-02", "2018-03", "2018-04", "2018-05", "2018-06", "2018-07", "2018-08", "2018-09", "2018-10", "2018-11", "2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12", "2020-01", "2020-02", "2020-03", "2020-04", "2020-05", "2020-06", "2020-07", "2020-08", "2020-09", "2020-10"], "y": [0.0, -0.10522236998193879, -2.0711282538934284, 5.406420696366987, -2.4157192810102646, 1.3429864095264366, 3.3352899080892673, 2.8002261223993186, -1.589619845396284, 1.4391664452487074, -0.7568086576579702, -2.93850044891365, 2.586709884427485, 2.312985207298235, 5.536523934067761, 0.45299105201670464, 2.276815779257446, 3.0438029362024555, -5.223151279729732, 0.43806512787836205, 0.35971509426524495, 0.8530156188298665, 7.048813764172479, 2.7614036533124997, -1.5077821149295123, 4.1165126315356515, 1.5850212722871015, -0.31638080592278905, 6.202359405981017, 0.17039915503982428, 0.3876670240909208, 3.97473597884872, 1.9836995887002162, 0.2620742526452391, -5.20684913830568, 5.80850945825111, -9.260137373517164, 9.893376843896107, 3.54708851374419, 4.272773702407928, 3.6651583806863286, -1.744585902136786, 5.610288275665742, 3.7920870652609295, -1.0497035652887288, 0.6392659372259191, 1.1301808150273818, 0.7412791440984723, 3.985966569964172, 5.468398506590066, -11.21094650123381, -12.158199938455038, 18.907546829241518, 7.868295816614346, -2.109245281908112, 5.07234885447736, 3.887598409972526, -3.7384198395463586, 0.603240301385144]}, {"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "60/40", "orientation": "v", "text": "", "type": "bar", "x": ["2015-12", "2016-01", "2016-02", "2016-03", "2016-04", "2016-05", "2016-06", "2016-07", "2016-08", "2016-09", "2016-10", "2016-11", "2016-12", "2017-01", "2017-02", "2017-03", "2017-04", "2017-05", "2017-06", "2017-07", "2017-08", "2017-09", "2017-10", "2017-11", "2017-12", "2018-01", "2018-02", "2018-03", "2018-04", "2018-05", "2018-06", "2018-07", "2018-08", "2018-09", "2018-10", "2018-11", "2018-12", "2019-01", "2019-02", "2019-03", "2019-04", "2019-05", "2019-06", "2019-07", "2019-08", "2019-09", "2019-10", "2019-11", "2019-12", "2020-01", "2020-02", "2020-03", "2020-04", "2020-05", "2020-06", "2020-07", "2020-08", "2020-09", "2020-10"], "y": [0.0, -1.6489594077294778, 0.6038433422144607, 2.856491260991545, -2.039104548002646, 2.3044921927781736, 1.1471825365586774, 4.066711814477886, 0.3422683437687146, 0.4417836996556179, -2.7817348726783764, -1.0923071615651425, 1.8582709561190125, 2.2030392765755025, 2.7880735463474915, 0.49779998205889964, 1.8145815490194783, 2.082510437510021, -0.784660585005037, 2.332498359315349, 1.64462420039444, -0.010676567805567583, 2.0051373531416283, 1.5096909771547873, 0.6827164503663052, 2.596453464064985, -1.5421155082202431, -0.24283282044506027, 0.8315464545910256, 3.4956509364827637, 0.08932852009315706, 0.35116191244997097, 3.9557975428479164, -1.1667122907381033, -6.323807022186134, -0.11784901951559235, -4.264795732103499, 5.506595649152568, 2.0295004974657527, 3.442674572779425, 1.8997456077382235, -2.109931262128373, 5.438261675006606, 0.807787597273335, 2.352634718506152 ...
